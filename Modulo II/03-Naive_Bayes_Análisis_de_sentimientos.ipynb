# %% [markdown]
# <div style="background-color:#000047; padding: 30px; border-radius: 10px; color: white; text-align: center;">
#     <img src='Figures/alinco_white_text.png' style="height: 100px; margin-bottom: 10px;"/>
#     <h1>Módulo 2:  Tareas Clásicas de NLP</h1>
#     <h2>Naive Bayes para Análisis de Sentimientos</h2>
# </div>

# %% [markdown]
# ## Que es el Analisis de Sentimientos?
#
# El **analisis de sentimientos** (*sentiment analysis*) es una tarea de NLP que consiste en determinar la **polaridad emocional** de un texto: positivo, negativo o neutro.
#
# **Ejemplos:**
# - *"Me encanto la pelicula, una obra maestra"* -> **Positivo**
# - *"Pesimo servicio, no vuelvo"* -> **Negativo**
# - *"El producto llego el martes"* -> **Neutro**
#
# **Aplicaciones reales:** monitoreo de redes sociales, resenas de productos, atencion al cliente, analisis de marca.

# %% [markdown]
# ## Que es Naive Bayes?
#
# **Naive Bayes** es un clasificador **probabilistico** basado en el **Teorema de Bayes**. Se le llama *"naive"* (ingenuo) porque asume que **todas las caracteristicas (palabras) son independientes entre si** dada la clase, una simplificacion que rara vez es cierta en el lenguaje, pero que funciona sorprendentemente bien.
#
# ### Teorema de Bayes
#
# $$P(C \mid X) = \frac{P(X \mid C)\,P(C)}{P(X)}$$
#
# Donde:
# - $P(C \mid X)$ = **posterior**: probabilidad de la clase $C$ (ej. "positivo") dado el texto $X$.
# - $P(X \mid C)$ = **verosimilitud** (*likelihood*): probabilidad de ver esas palabras en la clase $C$.
# - $P(C)$ = **prior**: probabilidad a priori de la clase (que tan frecuente es).
# - $P(X)$ = **evidencia**: probabilidad del texto (constante para todas las clases, se ignora al comparar).
#
# [Teorema de Bayes - Wikipedia](https://es.wikipedia.org/wiki/Teorema_de_Bayes)
#
# ##  La suposicion "ingenua (Naive)" (independencia condicional)
#
# Un texto $X$ se representa como un conjunto de palabras $(w_1, w_2, \dots, w_n)$. Naive Bayes asume que las palabras son **independientes** dada la clase:
#
# $$P(X \mid C) = P(w_1 \mid C)\cdot P(w_2 \mid C)\cdots P(w_n \mid C) = \prod_{i=1}^{n} P(w_i \mid C)$$
#
# Por lo tanto, la clase predicha es la que **maximiza**:
#
# $$\hat{C} = \arg\max_{C} \; P(C) \prod_{i=1}^{n} P(w_i \mid C)$$
#
# > **Definicion clave - "Bag of Words":** se ignora el orden de las palabras; solo importa **cuales** aparecen y **cuantas veces**.
#
# [Naive Bayes classifier - Wikipedia](https://en.wikipedia.org/wiki/Naive_Bayes_classifier)
#
# ## Suavizado de Laplace (*Laplace Smoothing*)
#
# **Problema:** si una palabra nunca aparecio en la clase "positivo" durante el entrenamiento, su probabilidad seria $0$, anulando todo el producto.
#
# **Solucion:** sumar $1$ a cada conteo (suavizado de Laplace o *add-one smoothing*):
#
# $$P(w_i \mid C) = \frac{\text{count}(w_i, C) + 1}{\sum_{w \in V}\big(\text{count}(w, C)\big) + |V|}$$
#
# Donde $|V|$ es el tamano del vocabulario.

# %% [markdown]
# ### La regla de Bayes para clasificacion de texto:
# $$\hat{c} = \arg\max_{c} \left[ \log P(c) + \sum_{i=1}^{n} \log P(w_i | c) \right]$$
#
# ### Enfoques:
# ```
# Lexicon:  Diccionario con polaridad por palabra  ->  sin entrenamiento, sin contexto
# ML:       TF-IDF + NB / SVM / LR               ->  generaliza bien, necesita datos
# DL:       LSTM / BERT                           ->  alta precision, costoso
# ```
#
# ## Ejemplo numerico paso a paso
#
# **Datos de entrenamiento:**
#
# | Texto | Clase |
# |-------|-------|
# | "buena pelicula" | Positivo |
# | "excelente actuacion" | Positivo |
# | "mala pelicula" | Negativo |
# | "aburrida y mala" | Negativo |
#
# **Queremos clasificar:** *"buena actuacion"*
#
# **Paso 1 - Priors:** 2 positivos y 2 negativos -> $P(\text{Pos}) = P(\text{Neg}) = 0.5$
#
# **Paso 2 - Vocabulario:** {buena, pelicula, excelente, actuacion, mala, aburrida, y} -> $|V| = 7$
#
# **Paso 3 - Verosimilitudes** (con suavizado de Laplace, 4 palabras por clase):
#
# $$P(\text{buena} \mid \text{Pos}) = \frac{1+1}{4+7} = \frac{2}{11}, \quad P(\text{actuacion} \mid \text{Pos}) = \frac{1+1}{4+7} = \frac{2}{11}$$
#
# $$P(\text{buena} \mid \text{Neg}) = \frac{0+1}{4+7} = \frac{1}{11}, \quad P(\text{actuacion} \mid \text{Neg}) = \frac{0+1}{4+7} = \frac{1}{11}$$
#
# **Paso 4 - Posteriores:**
#
# $$P(\text{Pos} \mid X) \propto 0.5 \times \tfrac{2}{11} \times \tfrac{2}{11} \approx 0.0165$$
#
# $$P(\text{Neg} \mid X) \propto 0.5 \times \tfrac{1}{11} \times \tfrac{1}{11} \approx 0.0041$$
#
# **Resultado:** $0.0165 > 0.0041$ -> se clasifica como **Positivo**
#
# > **Truco practico:** en la implementacion real se usan **logaritmos** ($\log$) para evitar el *underflow* numerico al multiplicar muchas probabilidades pequenas:
# > $$\log P(C) + \sum_i \log P(w_i \mid C)$$

# %% [markdown]
# ## Naive Bayes para Análisis de Sentimientos de tweets
#
# Aplicaremos Naive Bayes para el análisis de sentimientos de tweets, lo que haremos en este notebook será:
#
# * Entrenar un modelo de Naive Bayes para el análisis de sentimientos
# * Probaremos el modelo creado
# * Calcularemos las proporciones de palabras positivas a palabras negativas
# * Veremos una función de análisis de errores
# * Predeciremos un tweet

# %%
from utils_nb import process_tweet, lookup
import pdb
from nltk.corpus import stopwords, twitter_samples
import numpy as np
import pandas as pd
import nltk
import string
from nltk.tokenize import TweetTokenizer
from os import getcwd

# %%
nltk.download('stopwords')
nltk.download('twitter_samples')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\x\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     C:\Users\x\AppData\Roaming\nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# True

# %% [markdown]
# Si aún no se han descargado:
# ```
# nltk.download('stopwords')
# nltk.download('twitter_samples')
# ```

# %%
# add folder, tmp2, from our local workspace containing pre-downloaded corpora files to nltk's data path
filePath = f"{getcwd()}/../tmp2/"
nltk.data.path.append(filePath)

# %%
# get the sets of positive and negative tweets
all_positive_tweets = twitter_samples.strings('positive_tweets.json')
all_negative_tweets = twitter_samples.strings('negative_tweets.json')

# split the data into two pieces, one for training and one for testing (validation set)
test_pos = all_positive_tweets[4000:]
train_pos = all_positive_tweets[:4000]
test_neg = all_negative_tweets[4000:]
train_neg = all_negative_tweets[:4000]

train_x = train_pos + train_neg
test_x = test_pos + test_neg

# avoid assumptions about the length of all_positive_tweets
train_y = np.append(np.ones(len(train_pos)), np.zeros(len(train_neg)))
test_y = np.append(np.ones(len(test_pos)), np.zeros(len(test_neg)))

# %% [markdown]
# # Preprocesamiento de los datos
#
# Para cualquier proyecto de aprendizaje automático, una vez que se haya recopilado los datos, el primer paso es el preprocesamiento.
#
# - **Eliminar el ruido**: eliminar las palabras que no dicen mucho sobre el contenido. Estos incluyen todas las palabras comunes como 'I, you, are, is, etc...' que no nos darían suficiente información sobre el sentimiento.
# - También eliminaremos los tickers del mercado de valores, los símbolos de retuits, los hipervínculos y los hashtags porque no pueden brindarle mucha información sobre el sentimiento.
# - También hay que eliminar toda la puntuación de un tweet. La razón para hacer esto es porque queremos tratar las palabras con o sin puntuación como la misma palabra, en lugar de tratar las palabras "happy", "happy?", "happy!", "happy," and "happy." como palabras diferentes.
# - Por último, desea utilizaremos la técnica de stemming para realizar un seguimiento de una sola variación de cada palabra. En otras palabras, trataremos "motivation", "motivated", y "motivate" de manera similar agrupándolos dentro de la misma raíz de "motiv-".
#
# Recuerden que ya tenemos una función para esto (`process_tweet()`)

# %%
custom_tweet = "RT @Twitter @chapagain Hello There! Have a great day. :) #good #morning http://chapagain.com.np"
process_tweet(custom_tweet)
# Out:
# ['hello', 'great', 'day', ':)', 'good', 'morn']

# %% [markdown]
# ## Funciones de ayuda
#
# Para entrenar el modelo, necesitaremos construir un diccionario donde las claves sean una tupla (word, label) y los valores sean la frecuencia correspondiente. Las etiquetas de salida para definir que un tweet es positivo será 1 y para un tweet negativo será 0.
#
# Utilizaremos la función `lookup()` que toma del diccionario `freqs` una palabra y una etiqueta (1 or 0) y retorna el número de veces que la palabra y esa etiqueta aparecen en la collección de tweets.
#
# Por ejemplo: Dado una lista de sentencias en los tweets: `["i am rather excited", "you are rather happy"]` y la etiqueta 1, la función regresara el diccionario que contiene lo siguiente:
#
# {
#     ("rather", 1): 2
#     ("happi", 1) : 1
#     ("excit", 1) : 1
# }
#
# **Notas:**
# - Para cada palabra en la cadena dada, se asigna la misma etiqueta 1 a cada palabra.
# - Las palabras "i" y "am" no se guardan, ya que fue eliminada por process_tweet porque es una stopword.
# - La palabra "rather" aparece dos veces en la lista de tweets, por lo que su valor de recuento es 2.
#
# Crearemos una función `count_tweets()` que toma una lista de tweets como entrada, las limpia, y regresa un diccionario.
#
# - La clave en el diccionario es una tupla que contiene la palabra despues del stemming y su etiqueta de clase, Ej. ("happi", 1).
# - El valor del key, será la cantidad de veces que esta palabra aparece en la colección de tweets dada (un número entero).

# %%
def count_tweets(result, tweets, ys):
    for y, tweet in zip(ys, tweets):
        for word in process_tweet(tweet):
            # Definimos el key con la palabra y la etiqueta 
            pair = (word,y)

            # Si el Key existe en el diccionario, entonces incrementamos el conteo
            if pair in result:
                result[pair] += 1
            # Si el key es nuevo, entonces lo añadimos al diccionario con un conteo igual a 1
            else:
                result[pair] = 1
    return result

# %%
# Probemos la función
tweets = ['i am happy', 'i am tricked', 'i am sad', 'i am tired', 'i am tired']
result = {}
ys = [1, 0, 0, 0, 0]
print(count_tweets(result, tweets, ys))
# Out:
# {('happi', 1): 1, ('trick', 0): 1, ('sad', 0): 1, ('tire', 0): 2}

# %% [markdown]
# ### Entrenar el modelo usando Naive Bayes
#
# #### ¿Cómo entrenamos un clasificador con Naive Bayes ?
#
# - La primera parte del entrenamiento de un clasificador Naive Bayes es identificar el número de clases que tiene.
# - Crearemos una probabilidad para cada clase.
#
#
# $P(D_{pos})$ denota la probabilidad que el documento sea positivo.
# $P(D_{neg})$ denota la probabilidad que el documento sea negativo.
#
# Utilizaremos las fórmulas de la siguiente manera y almacenaremos los valores en un diccionario:
#
# $$P(D_{pos}) = \frac{D_{pos}}{D}\tag{1}$$
#
# $$P(D_{neg}) = \frac{D_{neg}}{D}\tag{2}$$
#
# Donde $ D $ es el número total de documentos, o tweets en este caso, $ D_ {pos} $ es el número total de tweets positivos y $ D_ {neg} $ es el número total de tweets negativos.

# %% [markdown]
# #### Prior y Logprior
#
# La probabilidad previa (prior) representa la probabilidad subyacente de la población (tweets) objetivo de que un tweet sea positivo frente a uno negativo. En otras palabras, si no tuviéramos información específica y seleccionáramos a ciegas un tweet del conjunto de la población, ¿cuál es la probabilidad de que sea positivo frente a que sea negativo? Ese es el "previo".
#
# El "prior" es el ratio de las probabilidades $\frac{P(D_{pos})}{P(D_{neg})}$. Podemos tomar el logaritmo del "prior" para cambiar su escala, y lo llamaremos logprior.
#
#
# $$\text{logprior} = log \left( \frac{P(D_{pos})}{P(D_{neg})} \right) = log \left( \frac{D_{pos}}{D_{neg}} \right)$$.
#
# Notemos que $log(\frac{A}{B})$ es igual a $log(A) - log(B)$.  Por lo tanto logprior puede calcularse como la diferencia de dos logaritmos (propiedad de logaritmos).
#
#
# $$\text{logprior} = \log (P(D_{pos})) - \log (P(D_{neg})) = \log (D_{pos}) - \log (D_{neg})\tag{3}$$

# %% [markdown]
# #### Probabilidad positiva y negativa de una palabra
# Para calcular la probabilidad positiva y la probabilidad negativa de una palabra específica en el vocabulario, usaremos las siguientes entradas:
#
# - $freq_{pos}$ y $freq_{neg}$ son las frecuencias de esa palabra específica en la clase positiva o negativa. En otras palabras, la frecuencia positiva de una palabra es el número de veces que se cuenta la palabra con la etiqueta 1.
# - $ N_ {pos} $ y $ N_ {neg} $ son el número total de palabras positivas y negativas para todos los documentos (para todos los tweets), respectivamente.
#
# - $V$ es el número de palabras únicas en todo el conjunto de documentos, para todas las clases, ya sean positivas o negativas.
#
# Los usaremos para calcular la probabilidad positiva y negativa de una palabra específica usando la fórmula:
#
# $$ P(W_{pos}) = \frac{freq_{pos} + 1}{N_{pos} + V}\tag{4} $$
# $$ P(W_{neg}) = \frac{freq_{neg} + 1}{N_{neg} + V}\tag{5} $$
#
# Note que añadimos "+1" en el numerador para el smoothing aditivo.  Este [artículo](https://en.wikipedia.org/wiki/Additive_smoothing) explica detalladamente sobre el smoothing aditivo.

# %% [markdown]
# #### Log likelihood
# Para calcular la loglikelihood (probabilidad mínima) de esa misma palabra, podemos implementar las siguientes ecuaciones:
#
# $$\text{loglikelihood} = \log \left(\frac{P(W_{pos})}{P(W_{neg})} \right)\tag{6}$$

# %% [markdown]
# ##### Creación del diccionario de  frecuencias (`freqs` )
# - Dada la función `count_tweets ()`, podemos calcular un diccionario llamado `freqs` que contiene todas las frecuencias.
# - En este diccionario `freqs`, la clave es la tupla (word,label)
# - El valor es el número de veces que ha aparecido.

# %%
# Obtenemos el diccionario de frecuencias 
freqs = count_tweets({}, train_x, train_y)
freqs
# Out:
# {('followfriday', np.float64(1.0)): 23,
#  ('top', np.float64(1.0)): 30,
#  ('engag', np.float64(1.0)): 7,
#  ('member', np.float64(1.0)): 14,
#  ('commun', np.float64(1.0)): 27,
#  ('week', np.float64(1.0)): 72,
#  (':)', np.float64(1.0)): 2847,
#  ('hey', np.float64(1.0)): 60,
#  ('jame', np.float64(1.0)): 7,
#  ('odd', np.float64(1.0)): 2,
#  (':/', np.float64(1.0)): 5,
#  ('pleas', np.float64(1.0)): 80,
#  ('call', np.float64(1.0)): 27,
#  ('contact', np.float64(1.0)): 4,
#  ('centr', np.float64(1.0)): 1,
#  ('02392441234', np.float64(1.0)): 1,
#  ('abl', np.float64(1.0)): 6,
#  ('assist', np.float64(1.0)): 1,
#  ('mani', np.float64(1.0)): 28,
#  ('thank', np.float64(1.0)): 504,
#  ('listen', np.float64(1.0)): 14,
#  ('last', np.float64(1.0)): 39,
#  ('night', np.float64(1.0)): 55,
#  ('bleed', np.float64(1.0)): 2,
#  ('amaz', np.float64(1.0)): 41,
#  ('track', np.float64(1.0)): 5,
#  ('scotland', np.float64(1.0)): 2,
#  ('congrat', np.float64(1.0)): 15,
#  ('yeaaah', np.float64(1.0)): 1,
#  ('yipppi', np.float64(1.0)): 1,
#  ('accnt', np.float64(1.0)): 2,
#  ('verifi', np.float64(1.0)): 2,
#  ('rqst', np.float64(1.0)): 1,
#  ('succeed', np.float64(1.0)): 1,
#  ('got', np.float64(1.0)): 57,
#  ('blue', np.float64(1.0)): 8,
#  ('tick', np.float64(1.0)): 1,
#  ('mark', np.float64(1.0)): 1,
#  ('fb', np.float64(1.0)): 4,
#  ('profil', np.float64(1.0)): 2,
#  ('15', np.float64(1.0)): 4,
#  ('day', np.float64(1.0)): 187,
#  ('one', np.float64(1.0)): 90,
#  ('irresist', np.float64(1.0)): 2,
#  ('flipkartfashionfriday', np.float64(1.0)): 16,
#  ('like', np.float64(1.0)): 187,
#  ('keep', np.float64(1.0)): 55,
#  ('love', np.float64(1.0)): 336,
#  ('custom', np.float64(1.0)): 4,
#  ('wait', np.float64(1.0)): 55,
#  ('long', np.float64(1.0)): 27,
#  ('hope', np.float64(1.0)): 113,
#  ('enjoy', np.float64(1.0)): 57,
#  ('happi', np.float64(1.0)): 161,
#  ('friday', np.float64(1.0)): 91,
#  ('lwwf', np.float64(1.0)): 1,
#  ('second', np.float64(1.0)): 8,
#  ('thought', np.float64(1.0)): 21,
#  ('’', np.float64(1.0)): 17,
#  ('enough', np.float64(1.0)): 16,
#  ('time', np.float64(1.0)): 100,
#  ('dd', np.float64(1.0)): 1,
#  ('new', np.float64(1.0)): 111,
#  ('short', np.float64(1.0)): 6,
#  ('enter', np.float64(1.0)): 9,
#  ('system', np.float64(1.0)): 2,
#  ('sheep', np.float64(1.0)): 1,
#  ('must', np.float64(1.0)): 14,
#  ('buy', np.float64(1.0)): 9,
#  ('jgh', np.float64(1.0)): 4,
#  ('go', np.float64(1.0)): 120,
#  ('bayan', np.float64(1.0)): 1,
#  (':d', np.float64(1.0)): 498,
#  ('bye', np.float64(1.0)): 5,
#  ('act', np.float64(1.0)): 6,
#  ('mischiev', np.float64(1.0)): 1,
#  ('etl', np.float64(1.0)): 1,
#  ('layer', np.float64(1.0)): 1,
#  ('in-hous', np.float64(1.0)): 1,
#  ('wareh', np.float64(1.0)): 1,
#  ('app', np.float64(1.0)): 12,
#  ('katamari', np.float64(1.0)): 1,
#  ('well', np.float64(1.0)): 66,
#  ('…', np.float64(1.0)): 31,
#  ('name', np.float64(1.0)): 12,
#  ('impli', np.float64(1.0)): 1,
#  (':p', np.float64(1.0)): 104,
#  ('influenc', np.float64(1.0)): 16,
#  ('big', np.float64(1.0)): 27,
#  ('...', np.float64(1.0)): 227,
#  ('juici', np.float64(1.0)): 3,
#  ('selfi', np.float64(1.0)): 11,
#  ('follow', np.float64(1.0)): 319,
#  ('perfect', np.float64(1.0)): 17,
#  ('alreadi', np.float64(1.0)): 19,
#  ('know', np.float64(1.0)): 120,
#  ("what'", np.float64(1.0)): 14,
#  ('great', np.float64(1.0)): 134,
#  ('opportun', np.float64(1.0)): 17,
#  ('junior', np.float64(1.0)): 2,
#  ('triathlet', np.float64(1.0)): 1,
#  ('age', np.float64(1.0)): 2,
#  ('12', np.float64(1.0)): 5,
#  ('13', np.float64(1.0)): 5,
#  ('gatorad', np.float64(1.0)): 1,
#  ('seri', np.float64(1.0)): 4,
#  ('get', np.float64(1.0)): 164,
#  ('entri', np.float64(1.0)): 3,
#  ('lay', np.float64(1.0)): 3,
#  ('greet', np.float64(1.0)): 4,
#  ('card', np.float64(1.0)): 6,
#  ('rang', np.float64(1.0)): 2,
#  ('print', np.float64(1.0)): 3,
#  ('today', np.float64(1.0)): 86,
#  ('job', np.float64(1.0)): 34,
#  (':-)', np.float64(1.0)): 543,
#  ("friend'", np.float64(1.0)): 3,
#  ('lunch', np.float64(1.0)): 3,
#  ('yummm', np.float64(1.0)): 1,
#  ('nostalgia', np.float64(1.0)): 1,
#  ('tb', np.float64(1.0)): 1,
#  ('ku', np.float64(1.0)): 1,
#  ('id', np.float64(1.0)): 8,
#  ('conflict', np.float64(1.0)): 1,
#  ('help', np.float64(1.0)): 37,
#  ("here'", np.float64(1.0)): 20,
#  ('screenshot', np.float64(1.0)): 2,
#  ('work', np.float64(1.0)): 88,
#  ('hi', np.float64(1.0)): 154,
#  ('liv', np.float64(1.0)): 2,
#  ('hello', np.float64(1.0)): 49,
#  ('need', np.float64(1.0)): 62,
#  ('someth', np.float64(1.0)): 25,
#  ('u', np.float64(1.0)): 136,
#  ('fm', np.float64(1.0)): 2,
#  ('twitter', np.float64(1.0)): 25,
#  ('—', np.float64(1.0)): 22,
#  ('sure', np.float64(1.0)): 37,
#  ('thing', np.float64(1.0)): 48,
#  ('dm', np.float64(1.0)): 34,
#  ('x', np.float64(1.0)): 50,
#  ('heard', np.float64(1.0)): 9,
#  ('four', np.float64(1.0)): 5,
#  ('season', np.float64(1.0)): 5,
#  ('pretti', np.float64(1.0)): 17,
#  ('dope', np.float64(1.0)): 2,
#  ('penthous', np.float64(1.0)): 1,
#  ('obv', np.float64(1.0)): 1,
#  ('gobigorgohom', np.float64(1.0)): 1,
#  ('fun', np.float64(1.0)): 45,
#  ("y'all", np.float64(1.0)): 3,
#  ('yeah', np.float64(1.0)): 30,
#  ('suppos', np.float64(1.0)): 6,
#  ('lol', np.float64(1.0)): 48,
#  ('chat', np.float64(1.0)): 9,
#  ('bit', np.float64(1.0)): 16,
#  ('youth', np.float64(1.0)): 14,
#  ('💅🏽', np.float64(1.0)): 1,
#  ('💋', np.float64(1.0)): 2,
#  ('seen', np.float64(1.0)): 6,
#  ('year', np.float64(1.0)): 33,
#  ('rest', np.float64(1.0)): 9,
#  ('goe', np.float64(1.0)): 4,
#  ('quickli', np.float64(1.0)): 3,
#  ('bed', np.float64(1.0)): 8,
#  ('music', np.float64(1.0)): 15,
#  ('fix', np.float64(1.0)): 6,
#  ('dream', np.float64(1.0)): 17,
#  ('spiritu', np.float64(1.0)): 1,
#  ('ritual', np.float64(1.0)): 1,
#  ('festiv', np.float64(1.0)): 7,
#  ('népal', np.float64(1.0)): 1,
#  ('begin', np.float64(1.0)): 4,
#  ('line-up', np.float64(1.0)): 4,
#  ('left', np.float64(1.0)): 10,
#  ('see', np.float64(1.0)): 156,
#  ('sarah', np.float64(1.0)): 4,
#  ('send', np.float64(1.0)): 17,
#  ('us', np.float64(1.0)): 91,
#  ('email', np.float64(1.0)): 22,
#  ('bitsy@bitdefender.com', np.float64(1.0)): 1,
#  ('asap', np.float64(1.0)): 5,
#  ('kik', np.float64(1.0)): 16,
#  ('hatessuc', np.float64(1.0)): 1,
#  ('32429', np.float64(1.0)): 1,
#  ('kikm', np.float64(1.0)): 1,
#  ('lgbt', np.float64(1.0)): 2,
#  ('tinder', np.float64(1.0)): 1,
#  ('nsfw', np.float64(1.0)): 1,
#  ('akua', np.float64(1.0)): 1,
#  ('cumshot', np.float64(1.0)): 1,
#  ('come', np.float64(1.0)): 63,
#  ('hous', np.float64(1.0)): 5,
#  ('nsn_supplement', np.float64(1.0)): 1,
#  ('effect', np.float64(1.0)): 2,
#  ('press', np.float64(1.0)): 1,
#  ('releas', np.float64(1.0)): 11,
#  ('distribut', np.float64(1.0)): 1,
#  ('result', np.float64(1.0)): 2,
#  ('link', np.float64(1.0)): 13,
#  ('remov', np.float64(1.0)): 3,
#  ('pressreleas', np.float64(1.0)): 1,
#  ('newsdistribut', np.float64(1.0)): 1,
#  ('bam', np.float64(1.0)): 44,
#  ('bestfriend', np.float64(1.0)): 50,
#  ('lot', np.float64(1.0)): 80,
#  ('warsaw', np.float64(1.0)): 44,
#  ('<3', np.float64(1.0)): 118,
#  ('x46', np.float64(1.0)): 1,
#  ('everyon', np.float64(1.0)): 45,
#  ('watch', np.float64(1.0)): 32,
#  ('documentari', np.float64(1.0)): 1,
#  ('earthl', np.float64(1.0)): 1,
#  ('youtub', np.float64(1.0)): 8,
#  ('support', np.float64(1.0)): 25,
#  ('buuut', np.float64(1.0)): 1,
#  ('oh', np.float64(1.0)): 44,
#  ('look', np.float64(1.0)): 109,
#  ('forward', np.float64(1.0)): 20,
#  ('visit', np.float64(1.0)): 25,
#  ('next', np.float64(1.0)): 37,
#  ('letsgetmessi', np.float64(1.0)): 1,
#  ('jo', np.float64(1.0)): 1,
#  ('make', np.float64(1.0)): 69,
#  ('feel', np.float64(1.0)): 33,
#  ('better', np.float64(1.0)): 40,
#  ('never', np.float64(1.0)): 31,
#  ('anyon', np.float64(1.0)): 7,
#  ('kpop', np.float64(1.0)): 1,
#  ('flesh', np.float64(1.0)): 1,
#  ('good', np.float64(1.0)): 191,
#  ('girl', np.float64(1.0)): 34,
#  ('best', np.float64(1.0)): 49,
#  ('wish', np.float64(1.0)): 29,
#  ('reason', np.float64(1.0)): 10,
#  ('epic', np.float64(1.0)): 1,
#  ('soundtrack', np.float64(1.0)): 1,
#  ('shout', np.float64(1.0)): 11,
#  ('ad', np.float64(1.0)): 10,
#  ('video', np.float64(1.0)): 29,
#  ('playlist', np.float64(1.0)): 5,
#  ('would', np.float64(1.0)): 70,
#  ('dear', np.float64(1.0)): 15,
#  ('jordan', np.float64(1.0)): 1,
#  ('okay', np.float64(1.0)): 31,
#  ('fake', np.float64(1.0)): 1,
#  ('gameplay', np.float64(1.0)): 1,
#  (';)', np.float64(1.0)): 22,
#  ('haha', np.float64(1.0)): 44,
#  ('im', np.float64(1.0)): 38,
#  ('kid', np.float64(1.0)): 13,
#  ('stuff', np.float64(1.0)): 11,
#  ('exactli', np.float64(1.0)): 5,
#  ('product', np.float64(1.0)): 11,
#  ('line', np.float64(1.0)): 6,
#  ('etsi', np.float64(1.0)): 1,
#  ('shop', np.float64(1.0)): 12,
#  ('check', np.float64(1.0)): 38,
#  ('vacat', np.float64(1.0)): 5,
#  ('recharg', np.float64(1.0)): 1,
#  ('normal', np.float64(1.0)): 5,
#  ('charger', np.float64(1.0)): 2,
#  ('asleep', np.float64(1.0)): 7,
#  ('talk', np.float64(1.0)): 37,
#  ('sooo', np.float64(1.0)): 6,
#  ('someon', np.float64(1.0)): 29,
#  ('text', np.float64(1.0)): 12,
#  ('ye', np.float64(1.0)): 60,
#  ('bet', np.float64(1.0)): 6,
#  ('fit', np.float64(1.0)): 2,
#  ('hear', np.float64(1.0)): 24,
#  ('speech', np.float64(1.0)): 1,
#  ('piti', np.float64(1.0)): 2,
#  ('green', np.float64(1.0)): 2,
#  ('garden', np.float64(1.0)): 5,
#  ('midnight', np.float64(1.0)): 1,
#  ('sun', np.float64(1.0)): 6,
#  ('beauti', np.float64(1.0)): 45,
#  ('canal', np.float64(1.0)): 1,
#  ('dasvidaniya', np.float64(1.0)): 1,
#  ('till', np.float64(1.0)): 16,
#  ('scout', np.float64(1.0)): 1,
#  ('sg', np.float64(1.0)): 1,
#  ('futur', np.float64(1.0)): 9,
#  ('wlan', np.float64(1.0)): 1,
#  ('pro', np.float64(1.0)): 4,
#  ('confer', np.float64(1.0)): 1,
#  ('asia', np.float64(1.0)): 1,
#  ('chang', np.float64(1.0)): 20,
#  ('lollipop', np.float64(1.0)): 1,
#  ('🍭', np.float64(1.0)): 1,
#  ('nez', np.float64(1.0)): 1,
#  ('agnezmo', np.float64(1.0)): 1,
#  ('oley', np.float64(1.0)): 1,
#  ('mama', np.float64(1.0)): 1,
#  ('stand', np.float64(1.0)): 6,
#  ('stronger', np.float64(1.0)): 1,
#  ('god', np.float64(1.0)): 14,
#  ('misti', np.float64(1.0)): 1,
#  ('babi', np.float64(1.0)): 17,
#  ('cute', np.float64(1.0)): 21,
#  ('woohoo', np.float64(1.0)): 3,
#  ("can't", np.float64(1.0)): 31,
#  ('sign', np.float64(1.0)): 9,
#  ('yet', np.float64(1.0)): 12,
#  ('still', np.float64(1.0)): 37,
#  ('think', np.float64(1.0)): 48,
#  ('mka', np.float64(1.0)): 5,
#  ('liam', np.float64(1.0)): 5,
#  ('access', np.float64(1.0)): 3,
#  ('welcom', np.float64(1.0)): 54,
#  ('stat', np.float64(1.0)): 51,
#  ('arriv', np.float64(1.0)): 57,
#  ('1', np.float64(1.0)): 60,
#  ('unfollow', np.float64(1.0)): 53,
#  ('via', np.float64(1.0)): 60,
#  ('surpris', np.float64(1.0)): 10,
#  ('figur', np.float64(1.0)): 5,
#  ('happybirthdayemilybett', np.float64(1.0)): 1,
#  ('sweet', np.float64(1.0)): 16,
#  ('talent', np.float64(1.0)): 4,
#  ('2', np.float64(1.0)): 41,
#  ('plan', np.float64(1.0)): 21,
#  ('drain', np.float64(1.0)): 1,
#  ('gotta', np.float64(1.0)): 4,
#  ('timezon', np.float64(1.0)): 1,
#  ('parent', np.float64(1.0)): 4,
#  ('proud', np.float64(1.0)): 11,
#  ('least', np.float64(1.0)): 14,
#  ('mayb', np.float64(1.0)): 17,
#  ('sometim', np.float64(1.0)): 11,
#  ('grade', np.float64(1.0)): 4,
#  ('al', np.float64(1.0)): 3,
#  ('grand', np.float64(1.0)): 4,
#  ('manila_bro', np.float64(1.0)): 1,
#  ('chosen', np.float64(1.0)): 1,
#  ('let', np.float64(1.0)): 57,
#  ('around', np.float64(1.0)): 14,
#  ('..', np.float64(1.0)): 100,
#  ('side', np.float64(1.0)): 13,
#  ('world', np.float64(1.0)): 23,
#  ('eh', np.float64(1.0)): 2,
#  ('take', np.float64(1.0)): 30,
#  ('care', np.float64(1.0)): 12,
#  ('final', np.float64(1.0)): 24,
#  ('fuck', np.float64(1.0)): 20,
#  ('weekend', np.float64(1.0)): 61,
#  ('real', np.float64(1.0)): 18,
#  ('x45', np.float64(1.0)): 1,
#  ('join', np.float64(1.0)): 21,
#  ('hushedcallwithfraydo', np.float64(1.0)): 1,
#  ('gift', np.float64(1.0)): 7,
#  ('yeahhh', np.float64(1.0)): 1,
#  ('hushedpinwithsammi', np.float64(1.0)): 2,
#  ('event', np.float64(1.0)): 7,
#  ('might', np.float64(1.0)): 21,
#  ('luv', np.float64(1.0)): 4,
#  ('realli', np.float64(1.0)): 66,
#  ('appreci', np.float64(1.0)): 28,
#  ('share', np.float64(1.0)): 41,
#  ('wow', np.float64(1.0)): 14,
#  ('tom', np.float64(1.0)): 5,
#  ('gym', np.float64(1.0)): 3,
#  ('monday', np.float64(1.0)): 7,
#  ('invit', np.float64(1.0)): 15,
#  ('scope', np.float64(1.0)): 5,
#  ('friend', np.float64(1.0)): 40,
#  ('nude', np.float64(1.0)): 1,
#  ('sleep', np.float64(1.0)): 35,
#  ('birthday', np.float64(1.0)): 53,
#  ('want', np.float64(1.0)): 69,
#  ('t-shirt', np.float64(1.0)): 2,
#  ('cool', np.float64(1.0)): 29,
#  ('haw', np.float64(1.0)): 1,
#  ('phela', np.float64(1.0)): 1,
#  ('mom', np.float64(1.0)): 7,
#  ('obvious', np.float64(1.0)): 1,
#  ('princ', np.float64(1.0)): 1,
#  ('charm', np.float64(1.0)): 1,
#  ('stage', np.float64(1.0)): 2,
#  ('luck', np.float64(1.0)): 26,
#  ('tyler', np.float64(1.0)): 1,
#  ('hipster', np.float64(1.0)): 1,
#  ('glass', np.float64(1.0)): 3,
#  ('marti', np.float64(1.0)): 2,
#  ('glad', np.float64(1.0)): 41,
#  ('done', np.float64(1.0)): 40,
#  ('afternoon', np.float64(1.0)): 7,
#  ('read', np.float64(1.0)): 27,
#  ('kahfi', np.float64(1.0)): 1,
#  ('finish', np.float64(1.0)): 15,
#  ('ohmyg', np.float64(1.0)): 1,
#  ('yaya', np.float64(1.0)): 3,
#  ('dub', np.float64(1.0)): 1,
#  ('stalk', np.float64(1.0)): 2,
#  ('ig', np.float64(1.0)): 3,
#  ('gondooo', np.float64(1.0)): 1,
#  ('moo', np.float64(1.0)): 2,
#  ('tologooo', np.float64(1.0)): 1,
#  ('becom', np.float64(1.0)): 8,
#  ('detail', np.float64(1.0)): 8,
#  ('zzz', np.float64(1.0)): 1,
#  ('xx', np.float64(1.0)): 33,
#  ('physiotherapi', np.float64(1.0)): 1,
#  ('hashtag', np.float64(1.0)): 3,
#  ('💪', np.float64(1.0)): 1,
#  ('monica', np.float64(1.0)): 1,
#  ('miss', np.float64(1.0)): 17,
#  ('sound', np.float64(1.0)): 20,
#  ('morn', np.float64(1.0)): 68,
#  ("that'", np.float64(1.0)): 49,
#  ('x43', np.float64(1.0)): 1,
#  ('definit', np.float64(1.0)): 20,
#  ('tri', np.float64(1.0)): 34,
#  ('tonight', np.float64(1.0)): 15,
#  ('took', np.float64(1.0)): 7,
#  ('advic', np.float64(1.0)): 6,
#  ('treviso', np.float64(1.0)): 1,
#  ('concert', np.float64(1.0)): 23,
#  ('citi', np.float64(1.0)): 26,
#  ('countri', np.float64(1.0)): 22,
#  ('start', np.float64(1.0)): 56,
#  ('fine', np.float64(1.0)): 7,
#  ('gorgeou', np.float64(1.0)): 9,
#  ('xo', np.float64(1.0)): 2,
#  ('oven', np.float64(1.0)): 2,
#  ('roast', np.float64(1.0)): 1,
#  ('garlic', np.float64(1.0)): 1,
#  ('oliv', np.float64(1.0)): 1,
#  ('oil', np.float64(1.0)): 4,
#  ('dri', np.float64(1.0)): 4,
#  ('tomato', np.float64(1.0)): 1,
#  ('basil', np.float64(1.0)): 1,
#  ('centuri', np.float64(1.0)): 1,
#  ('tuna', np.float64(1.0)): 1,
#  ('right', np.float64(1.0)): 38,
#  ('back', np.float64(1.0)): 74,
#  ('atchya', np.float64(1.0)): 1,
#  ('even', np.float64(1.0)): 26,
#  ('almost', np.float64(1.0)): 8,
#  ('chanc', np.float64(1.0)): 3,
#  ('cheer', np.float64(1.0)): 17,
#  ('po', np.float64(1.0)): 3,
#  ('ice', np.float64(1.0)): 6,
#  ('cream', np.float64(1.0)): 6,
#  ('agre', np.float64(1.0)): 13,
#  ('100', np.float64(1.0)): 6,
#  ('heheheh', np.float64(1.0)): 2,
#  ('that', np.float64(1.0)): 10,
#  ('point', np.float64(1.0)): 11,
#  ('stay', np.float64(1.0)): 20,
#  ('home', np.float64(1.0)): 20,
#  ('soon', np.float64(1.0)): 38,
#  ('promis', np.float64(1.0)): 4,
#  ('web', np.float64(1.0)): 4,
#  ('whatsapp', np.float64(1.0)): 3,
#  ('volta', np.float64(1.0)): 1,
#  ('funcionar', np.float64(1.0)): 1,
#  ('com', np.float64(1.0)): 2,
#  ('iphon', np.float64(1.0)): 7,
#  ('jailbroken', np.float64(1.0)): 1,
#  ('later', np.float64(1.0)): 11,
#  ('34', np.float64(1.0)): 3,
#  ('min', np.float64(1.0)): 7,
#  ('leia', np.float64(1.0)): 1,
#  ('appear', np.float64(1.0)): 3,
#  ('hologram', np.float64(1.0)): 1,
#  ('r2d2', np.float64(1.0)): 1,
#  ('w', np.float64(1.0)): 16,
#  ('messag', np.float64(1.0)): 9,
#  ('obi', np.float64(1.0)): 1,
#  ('wan', np.float64(1.0)): 1,
#  ('sit', np.float64(1.0)): 7,
#  ('luke', np.float64(1.0)): 4,
#  ('inter', np.float64(1.0)): 1,
#  ('3', np.float64(1.0)): 25,
#  ('ucl', np.float64(1.0)): 1,
#  ('arsen', np.float64(1.0)): 2,
#  ('small', np.float64(1.0)): 1,
#  ('team', np.float64(1.0)): 24,
#  ('pass', np.float64(1.0)): 10,
#  ('🚂', np.float64(1.0)): 1,
#  ('dewsburi', np.float64(1.0)): 2,
#  ('railway', np.float64(1.0)): 1,
#  ('station', np.float64(1.0)): 4,
#  ('dew', np.float64(1.0)): 1,
#  ('west', np.float64(1.0)): 1,
#  ('yorkshir', np.float64(1.0)): 2,
#  ('430', np.float64(1.0)): 1,
#  ('smh', np.float64(1.0)): 2,
#  ('9:25', np.float64(1.0)): 1,
#  ('live', np.float64(1.0)): 21,
#  ('strang', np.float64(1.0)): 4,
#  ('imagin', np.float64(1.0)): 5,
#  ('megan', np.float64(1.0)): 1,
#  ('masaantoday', np.float64(1.0)): 4,
#  ('a4', np.float64(1.0)): 3,
#  ('shweta', np.float64(1.0)): 1,
#  ('tripathi', np.float64(1.0)): 1,
#  ('5', np.float64(1.0)): 15,
#  ('20', np.float64(1.0)): 5,
#  ('kurta', np.float64(1.0)): 3,
#  ('half', np.float64(1.0)): 6,
#  ('number', np.float64(1.0)): 11,
#  ('wsalelov', np.float64(1.0)): 14,
#  ('ah', np.float64(1.0)): 12,
#  ('larri', np.float64(1.0)): 3,
#  ('anyway', np.float64(1.0)): 14,
#  ('kinda', np.float64(1.0)): 12,
#  ('goood', np.float64(1.0)): 1,
#  ('life', np.float64(1.0)): 36,
#  ('enn', np.float64(1.0)): 1,
#  ('could', np.float64(1.0)): 25,
#  ('warmup', np.float64(1.0)): 1,
#  ('15th', np.float64(1.0)): 2,
#  ('bath', np.float64(1.0)): 6,
#  ('dum', np.float64(1.0)): 2,
#  ('andar', np.float64(1.0)): 1,
#  ('ram', np.float64(1.0)): 1,
#  ('sampath', np.float64(1.0)): 1,
#  ('sona', np.float64(1.0)): 1,
#  ('mohapatra', np.float64(1.0)): 1,
#  ('samantha', np.float64(1.0)): 1,
#  ('edward', np.float64(1.0)): 1,
#  ('mein', np.float64(1.0)): 1,
#  ('tulan', np.float64(1.0)): 1,
#  ('razi', np.float64(1.0)): 2,
#  ('wah', np.float64(1.0)): 2,
#  ('josh', np.float64(1.0)): 1,
#  ('alway', np.float64(1.0)): 48,
#  ('smile', np.float64(1.0)): 47,
#  ('pictur', np.float64(1.0)): 7,
#  ('16.20', np.float64(1.0)): 1,
#  ('giveitup', np.float64(1.0)): 1,
#  ('given', np.float64(1.0)): 3,
#  ('ga', np.float64(1.0)): 3,
#  ('subsidi', np.float64(1.0)): 1,
#  ('initi', np.float64(1.0)): 2,
#  ('propos', np.float64(1.0)): 3,
#  ('delight', np.float64(1.0)): 4,
#  ('yesterday', np.float64(1.0)): 4,
#  ('x42', np.float64(1.0)): 1,
#  ('lmaoo', np.float64(1.0)): 2,
#  ('song', np.float64(1.0)): 16,
#  ('ever', np.float64(1.0)): 19,
#  ('shall', np.float64(1.0)): 5,
#  ('littl', np.float64(1.0)): 29,
#  ('throwback', np.float64(1.0)): 3,
#  ('outli', np.float64(1.0)): 1,
#  ('island', np.float64(1.0)): 2,
#  ('cheung', np.float64(1.0)): 1,
#  ('chau', np.float64(1.0)): 1,
#  ('mui', np.float64(1.0)): 1,
#  ('wo', np.float64(1.0)): 1,
#  ('total', np.float64(1.0)): 5,
#  ('differ', np.float64(1.0)): 10,
#  ('kfckitchentour', np.float64(1.0)): 2,
#  ('kitchen', np.float64(1.0)): 3,
#  ('clean', np.float64(1.0)): 1,
#  ('cusp', np.float64(1.0)): 1,
#  ('test', np.float64(1.0)): 7,
#  ('water', np.float64(1.0)): 7,
#  ('reward', np.float64(1.0)): 1,
#  ('arummzz', np.float64(1.0)): 2,
#  ("let'", np.float64(1.0)): 18,
#  ('drive', np.float64(1.0)): 9,
#  ('travel', np.float64(1.0)): 19,
#  ('yogyakarta', np.float64(1.0)): 3,
#  ('jeep', np.float64(1.0)): 3,
#  ('indonesia', np.float64(1.0)): 3,
#  ('instamood', np.float64(1.0)): 3,
#  ('wanna', np.float64(1.0)): 23,
#  ('skype', np.float64(1.0)): 3,
#  ('may', np.float64(1.0)): 16,
#  ('nice', np.float64(1.0)): 70,
#  ('friendli', np.float64(1.0)): 1,
#  ('pretend', np.float64(1.0)): 2,
#  ('film', np.float64(1.0)): 8,
#  ('congratul', np.float64(1.0)): 9,
#  ('winner', np.float64(1.0)): 3,
#  ('cheesydelight', np.float64(1.0)): 1,
#  ('contest', np.float64(1.0)): 5,
#  ('address', np.float64(1.0)): 8,
#  ('guy', np.float64(1.0)): 48,
#  ('market', np.float64(1.0)): 5,
#  ('24/7', np.float64(1.0)): 1,
#  ('14', np.float64(1.0)): 1,
#  ('hour', np.float64(1.0)): 24,
#  ('leav', np.float64(1.0)): 11,
#  ('without', np.float64(1.0)): 9,
#  ('delay', np.float64(1.0)): 1,
#  ('actual', np.float64(1.0)): 13,
#  ('easi', np.float64(1.0)): 7,
#  ('guess', np.float64(1.0)): 8,
#  ('train', np.float64(1.0)): 7,
#  ('wd', np.float64(1.0)): 1,
#  ('shift', np.float64(1.0)): 4,
#  ('engin', np.float64(1.0)): 1,
#  ('etc', np.float64(1.0)): 2,
#  ('sunburn', np.float64(1.0)): 1,
#  ('peel', np.float64(1.0)): 2,
#  ('blog', np.float64(1.0)): 27,
#  ('huge', np.float64(1.0)): 9,
#  ('warm', np.float64(1.0)): 4,
#  ('☆', np.float64(1.0)): 3,
#  ('complet', np.float64(1.0)): 10,
#  ('triangl', np.float64(1.0)): 2,
#  ('northern', np.float64(1.0)): 1,
#  ('ireland', np.float64(1.0)): 2,
#  ('sight', np.float64(1.0)): 1,
#  ('smthng', np.float64(1.0)): 2,
#  ('fr', np.float64(1.0)): 3,
#  ('hug', np.float64(1.0)): 11,
#  ('xoxo', np.float64(1.0)): 3,
#  ('uu', np.float64(1.0)): 1,
#  ('jaann', np.float64(1.0)): 1,
#  ('topnewfollow', np.float64(1.0)): 2,
#  ('connect', np.float64(1.0)): 13,
#  ('wonder', np.float64(1.0)): 26,
#  ('made', np.float64(1.0)): 38,
#  ('fluffi', np.float64(1.0)): 1,
#  ('insid', np.float64(1.0)): 7,
#  ('pirouett', np.float64(1.0)): 1,
#  ('moos', np.float64(1.0)): 1,
#  ('trip', np.float64(1.0)): 12,
#  ('philli', np.float64(1.0)): 1,
#  ('decemb', np.float64(1.0)): 2,
#  ('dude', np.float64(1.0)): 6,
#  ('x41', np.float64(1.0)): 1,
#  ('question', np.float64(1.0)): 15,
#  ('flaw', np.float64(1.0)): 1,
#  ('pain', np.float64(1.0)): 8,
#  ('negat', np.float64(1.0)): 1,
#  ('strength', np.float64(1.0)): 2,
#  ('went', np.float64(1.0)): 10,
#  ('solo', np.float64(1.0)): 4,
#  ('move', np.float64(1.0)): 9,
#  ('fav', np.float64(1.0)): 11,
#  ('nirvana', np.float64(1.0)): 1,
#  ('smell', np.float64(1.0)): 2,
#  ('teen', np.float64(1.0)): 3,
#  ('spirit', np.float64(1.0)): 1,
#  ('rip', np.float64(1.0)): 3,
#  ('ami', np.float64(1.0)): 4,
#  ('winehous', np.float64(1.0)): 1,
#  ('coupl', np.float64(1.0)): 5,
#  ('tomhiddleston', np.float64(1.0)): 1,
#  ('elizabetholsen', np.float64(1.0)): 1,
#  ('yaytheylookgreat', np.float64(1.0)): 1,
#  ('goodnight', np.float64(1.0)): 18,
#  ('vid', np.float64(1.0)): 8,
#  ('wake', np.float64(1.0)): 10,
#  ('gonna', np.float64(1.0)): 16,
#  ('shoot', np.float64(1.0)): 5,
#  ('itti', np.float64(1.0)): 2,
#  ('bitti', np.float64(1.0)): 2,
#  ('teeni', np.float64(1.0)): 2,
#  ('bikini', np.float64(1.0)): 3,
#  ('much', np.float64(1.0)): 73,
#  ('4th', np.float64(1.0)): 4,
#  ('togeth', np.float64(1.0)): 6,
#  ('end', np.float64(1.0)): 13,
#  ('xfile', np.float64(1.0)): 1,
#  ('content', np.float64(1.0)): 3,
#  ('rain', np.float64(1.0)): 18,
#  ('fabul', np.float64(1.0)): 4,
#  ('fantast', np.float64(1.0)): 8,
#  ('♡', np.float64(1.0)): 12,
#  ('jb', np.float64(1.0)): 1,
#  ('forev', np.float64(1.0)): 5,
#  ('belieb', np.float64(1.0)): 3,
#  ('nighti', np.float64(1.0)): 1,
#  ('bug', np.float64(1.0)): 2,
#  ('bite', np.float64(1.0)): 1,
#  ('bracelet', np.float64(1.0)): 2,
#  ('idea', np.float64(1.0)): 23,
#  ('foundri', np.float64(1.0)): 1,
#  ('game', np.float64(1.0)): 23,
#  ('sens', np.float64(1.0)): 6,
#  ('pic', np.float64(1.0)): 21,
#  ('ef', np.float64(1.0)): 1,
#  ('phone', np.float64(1.0)): 16,
#  ('woot', np.float64(1.0)): 2,
#  ('derek', np.float64(1.0)): 1,
#  ('use', np.float64(1.0)): 32,
#  ('parkshar', np.float64(1.0)): 1,
#  ('gloucestershir', np.float64(1.0)): 1,
#  ('aaaahhh', np.float64(1.0)): 1,
#  ('man', np.float64(1.0)): 16,
#  ('traffic', np.float64(1.0)): 2,
#  ('stress', np.float64(1.0)): 4,
#  ('reliev', np.float64(1.0)): 1,
#  ("how'r", np.float64(1.0)): 1,
#  ('arbeloa', np.float64(1.0)): 1,
#  ('turn', np.float64(1.0)): 13,
#  ('17', np.float64(1.0)): 2,
#  ('omg', np.float64(1.0)): 13,
#  ('say', np.float64(1.0)): 43,
#  ('europ', np.float64(1.0)): 1,
#  ('rise', np.float64(1.0)): 2,
#  ('find', np.float64(1.0)): 20,
#  ('hard', np.float64(1.0)): 9,
#  ('believ', np.float64(1.0)): 7,
#  ('uncount', np.float64(1.0)): 1,
#  ('coz', np.float64(1.0)): 2,
#  ('unlimit', np.float64(1.0)): 1,
#  ('cours', np.float64(1.0)): 11,
#  ('teamposit', np.float64(1.0)): 1,
#  ('aldub', np.float64(1.0)): 2,
#  ('☕', np.float64(1.0)): 3,
#  ('rita', np.float64(1.0)): 2,
#  ('info', np.float64(1.0)): 10,
#  ('way', np.float64(1.0)): 34,
#  ('boy', np.float64(1.0)): 13,
#  ('x40', np.float64(1.0)): 1,
#  ('true', np.float64(1.0)): 19,
#  ('sethi', np.float64(1.0)): 2,
#  ('high', np.float64(1.0)): 6,
#  ('exe', np.float64(1.0)): 1,
#  ('skeem', np.float64(1.0)): 1,
#  ('saam', np.float64(1.0)): 1,
#  ('peopl', np.float64(1.0)): 42,
#  ('polit', np.float64(1.0)): 2,
#  ('izzat', np.float64(1.0)): 1,
#  ('wese', np.float64(1.0)): 1,
#  ('trust', np.float64(1.0)): 7,
#  ('khawateen', np.float64(1.0)): 1,
#  ('k', np.float64(1.0)): 8,
#  ('sath', np.float64(1.0)): 2,
#  ('mana', np.float64(1.0)): 1,
#  ('kar', np.float64(1.0)): 1,
#  ('deya', np.float64(1.0)): 1,
#  ('sort', np.float64(1.0)): 7,
#  ('smart', np.float64(1.0)): 5,
#  ('hair', np.float64(1.0)): 7,
#  ('tbh', np.float64(1.0)): 5,
#  ('jacob', np.float64(1.0)): 2,
#  ('g', np.float64(1.0)): 7,
#  ('upgrad', np.float64(1.0)): 2,
#  ('tee', np.float64(1.0)): 2,
#  ('famili', np.float64(1.0)): 14,
#  ('person', np.float64(1.0)): 14,
#  ('two', np.float64(1.0)): 15,
#  ('convers', np.float64(1.0)): 6,
#  ('onlin', np.float64(1.0)): 4,
#  ('mclaren', np.float64(1.0)): 1,
#  ('fridayfeel', np.float64(1.0)): 5,
#  ('tgif', np.float64(1.0)): 8,
#  ('squar', np.float64(1.0)): 1,
#  ('enix', np.float64(1.0)): 1,
#  ('bissmillah', np.float64(1.0)): 1,
#  ('ya', np.float64(1.0)): 19,
#  ('allah', np.float64(1.0)): 3,
#  ('socent', np.float64(1.0)): 1,
#  ('startup', np.float64(1.0)): 2,
#  ('drop', np.float64(1.0)): 9,
#  ('your', np.float64(1.0)): 3,
#  ('arnd', np.float64(1.0)): 1,
#  ('town', np.float64(1.0)): 3,
#  ('basic', np.float64(1.0)): 4,
#  ('piss', np.float64(1.0)): 2,
#  ('cup', np.float64(1.0)): 4,
#  ('also', np.float64(1.0)): 28,
#  ('terribl', np.float64(1.0)): 2,
#  ('complic', np.float64(1.0)): 1,
#  ('discuss', np.float64(1.0)): 2,
#  ('snapchat', np.float64(1.0)): 31,
#  ('lynettelow', np.float64(1.0)): 1,
#  ('kikmenow', np.float64(1.0)): 2,
#  ('snapm', np.float64(1.0)): 1,
#  ('hot', np.float64(1.0)): 20,
#  ('amazon', np.float64(1.0)): 1,
#  ('kikmeguy', np.float64(1.0)): 2,
#  ('defin', np.float64(1.0)): 2,
#  ('grow', np.float64(1.0)): 6,
#  ('sport', np.float64(1.0)): 4,
#  ('rt', np.float64(1.0)): 9,
#  ('rakyat', np.float64(1.0)): 1,
#  ('write', np.float64(1.0)): 11,
#  ('sinc', np.float64(1.0)): 11,
#  ('mention', np.float64(1.0)): 18,
#  ('fli', np.float64(1.0)): 5,
#  ('fish', np.float64(1.0)): 3,
#  ('promot', np.float64(1.0)): 3,
#  ('post', np.float64(1.0)): 16,
#  ('cyber', np.float64(1.0)): 1,
#  ('ourdaughtersourprid', np.float64(1.0)): 3,
#  ('mypapamyprid', np.float64(1.0)): 2,
#  ('papa', np.float64(1.0)): 1,
#  ('coach', np.float64(1.0)): 2,
#  ('posit', np.float64(1.0)): 3,
#  ('kha', np.float64(1.0)): 1,
#  ('atleast', np.float64(1.0)): 2,
#  ('x39', np.float64(1.0)): 1,
#  ('mango', np.float64(1.0)): 1,
#  ("lassi'", np.float64(1.0)): 1,
#  ("monty'", np.float64(1.0)): 1,
#  ('marvel', np.float64(1.0)): 2,
#  ('though', np.float64(1.0)): 16,
#  ('suspect', np.float64(1.0)): 3,
#  ('meant', np.float64(1.0)): 2,
#  ('24', np.float64(1.0)): 3,
#  ('hr', np.float64(1.0)): 2,
#  ('touch', np.float64(1.0)): 7,
#  ('kepler', np.float64(1.0)): 3,
#  ('452b', np.float64(1.0)): 4,
#  ('chalna', np.float64(1.0)): 1,
#  ('hai', np.float64(1.0)): 7,
#  ('thankyou', np.float64(1.0)): 12,
#  ('hazel', np.float64(1.0)): 1,
#  ('food', np.float64(1.0)): 6,
#  ('brooklyn', np.float64(1.0)): 1,
#  ('pta', np.float64(1.0)): 2,
#  ('awak', np.float64(1.0)): 8,
#  ('okayi', np.float64(1.0)): 2,
#  ('awww', np.float64(1.0)): 12,
#  ('ha', np.float64(1.0)): 18,
#  ('doc', np.float64(1.0)): 1,
#  ('splendid', np.float64(1.0)): 1,
#  ('spam', np.float64(1.0)): 1,
#  ('folder', np.float64(1.0)): 1,
#  ('amount', np.float64(1.0)): 1,
#  ('nigeria', np.float64(1.0)): 1,
#  ('claim', np.float64(1.0)): 1,
#  ('rted', np.float64(1.0)): 1,
#  ('leg', np.float64(1.0)): 3,
#  ('hurt', np.float64(1.0)): 4,
#  ('bad', np.float64(1.0)): 14,
#  ('mine', np.float64(1.0)): 11,
#  ('saturday', np.float64(1.0)): 5,
#  ('thaaank', np.float64(1.0)): 1,
#  ('puhon', np.float64(1.0)): 1,
#  ('happinesss', np.float64(1.0)): 1,
#  ('tnc', np.float64(1.0)): 1,
#  ('prior', np.float64(1.0)): 1,
#  ('notif', np.float64(1.0)): 2,
#  ('fat', np.float64(1.0)): 1,
#  ('co', np.float64(1.0)): 1,
#  ('probabl', np.float64(1.0)): 7,
#  ('ate', np.float64(1.0)): 4,
#  ('yuna', np.float64(1.0)): 2,
#  ('tamesid', np.float64(1.0)): 1,
#  ('´', np.float64(1.0)): 3,
#  ('googl', np.float64(1.0)): 5,
#  ('account', np.float64(1.0)): 17,
#  ('scouser', np.float64(1.0)): 1,
#  ('everyth', np.float64(1.0)): 10,
#  ('zoe', np.float64(1.0)): 1,
#  ('mate', np.float64(1.0)): 5,
#  ('liter', np.float64(1.0)): 5,
#  ('samee', np.float64(1.0)): 1,
#  ('edgar', np.float64(1.0)): 1,
#  ('updat', np.float64(1.0)): 12,
#  ('log', np.float64(1.0)): 3,
#  ('bring', np.float64(1.0)): 12,
#  ('abe', np.float64(1.0)): 1,
#  ('meet', np.float64(1.0)): 26,
#  ('x38', np.float64(1.0)): 1,
#  ('sigh', np.float64(1.0)): 3,
#  ('dreamili', np.float64(1.0)): 1,
#  ('pout', np.float64(1.0)): 1,
#  ('eye', np.float64(1.0)): 12,
#  ('quacketyquack', np.float64(1.0)): 6,
#  ('funni', np.float64(1.0)): 15,
#  ('happen', np.float64(1.0)): 13,
#  ('phil', np.float64(1.0)): 1,
#  ('em', np.float64(1.0)): 2,
#  ('del', np.float64(1.0)): 1,
#  ('rodder', np.float64(1.0)): 1,
#  ('els', np.float64(1.0)): 8,
#  ('play', np.float64(1.0)): 37,
#  ('newest', np.float64(1.0)): 1,
#  ('gamejam', np.float64(1.0)): 1,
#  ('irish', np.float64(1.0)): 2,
#  ('literatur', np.float64(1.0)): 2,
#  ('inaccess', np.float64(1.0)): 2,
#  ("kareena'", np.float64(1.0)): 2,
#  ('fan', np.float64(1.0)): 21,
#  ('brain', np.float64(1.0)): 10,
#  ('dot', np.float64(1.0)): 8,
#  ('braindot', np.float64(1.0)): 8,
#  ('fair', np.float64(1.0)): 4,
#  ('rush', np.float64(1.0)): 1,
#  ('either', np.float64(1.0)): 10,
#  ('brandi', np.float64(1.0)): 1,
#  ('18', np.float64(1.0)): 5,
#  ('carniv', np.float64(1.0)): 1,
#  ('men', np.float64(1.0)): 8,
#  ('put', np.float64(1.0)): 11,
#  ('mask', np.float64(1.0)): 2,
#  ('xavier', np.float64(1.0)): 1,
#  ('forneret', np.float64(1.0)): 1,
#  ('jennif', np.float64(1.0)): 1,
#  ('site', np.float64(1.0)): 7,
#  ('free', np.float64(1.0)): 31,
#  ('50.000', np.float64(1.0)): 3,
#  ('8', np.float64(1.0)): 10,
#  ('ball', np.float64(1.0)): 7,
#  ('pool', np.float64(1.0)): 5,
#  ('coin', np.float64(1.0)): 5,
#  ('edit', np.float64(1.0)): 6,
#  ('trish', np.float64(1.0)): 1,
#  ('♥', np.float64(1.0)): 13,
#  ('grate', np.float64(1.0)): 5,
#  ('three', np.float64(1.0)): 8,
#  ('comment', np.float64(1.0)): 7,
#  ('wakeup', np.float64(1.0)): 1,
#  ('besid', np.float64(1.0)): 2,
#  ('dirti', np.float64(1.0)): 2,
#  ('sex', np.float64(1.0)): 4,
#  ('lmaooo', np.float64(1.0)): 1,
#  ('😤', np.float64(1.0)): 2,
#  ('loui', np.float64(1.0)): 4,
#  ('throw', np.float64(1.0)): 3,
#  ('caus', np.float64(1.0)): 11,
#  ('inspir', np.float64(1.0)): 6,
#  ('ff', np.float64(1.0)): 40,
#  ('twoof', np.float64(1.0)): 3,
#  ('gr8', np.float64(1.0)): 1,
#  ('wkend', np.float64(1.0)): 3,
#  ('kind', np.float64(1.0)): 22,
#  ('exhaust', np.float64(1.0)): 2,
#  ('word', np.float64(1.0)): 17,
#  ('cheltenham', np.float64(1.0)): 1,
#  ('area', np.float64(1.0)): 4,
#  ('kale', np.float64(1.0)): 1,
#  ('crisp', np.float64(1.0)): 1,
#  ('ruin', np.float64(1.0)): 5,
#  ('x37', np.float64(1.0)): 1,
#  ('open', np.float64(1.0)): 12,
#  ('worldwid', np.float64(1.0)): 2,
#  ('outta', np.float64(1.0)): 1,
#  ('sfvbeta', np.float64(1.0)): 1,
#  ('vantast', np.float64(1.0)): 1,
#  ('xcylin', np.float64(1.0)): 1,
#  ('bundl', np.float64(1.0)): 1,
#  ('show', np.float64(1.0)): 20,
#  ('internet', np.float64(1.0)): 2,
#  ('price', np.float64(1.0)): 3,
#  ('realisticli', np.float64(1.0)): 1,
#  ('pay', np.float64(1.0)): 8,
#  ('net', np.float64(1.0)): 1,
#  ('educ', np.float64(1.0)): 1,
#  ('power', np.float64(1.0)): 6,
#  ('weapon', np.float64(1.0)): 1,
#  ('nelson', np.float64(1.0)): 1,
#  ('mandela', np.float64(1.0)): 1,
#  ('recent', np.float64(1.0)): 8,
#  ('j', np.float64(1.0)): 2,
#  ('chenab', np.float64(1.0)): 1,
#  ('flow', np.float64(1.0)): 5,
#  ('pakistan', np.float64(1.0)): 1,
#  ('incredibleindia', np.float64(1.0)): 1,
#  ('teenchoic', np.float64(1.0)): 7,
#  ('choiceinternationalartist', np.float64(1.0)): 7,
#  ('superjunior', np.float64(1.0)): 7,
#  ('caught', np.float64(1.0)): 4,
#  ('first', np.float64(1.0)): 41,
#  ('salmon', np.float64(1.0)): 1,
#  ('super-blend', np.float64(1.0)): 1,
#  ('project', np.float64(1.0)): 6,
#  ('youth@bipolaruk.org.uk', np.float64(1.0)): 1,
#  ('awesom', np.float64(1.0)): 35,
#  ('stream', np.float64(1.0)): 12,
#  ('alma', np.float64(1.0)): 1,
#  ('mater', np.float64(1.0)): 1,
#  ('highschoolday', np.float64(1.0)): 1,
#  ('clientvisit', np.float64(1.0)): 1,
#  ('faith', np.float64(1.0)): 3,
#  ('christian', np.float64(1.0)): 1,
#  ('school', np.float64(1.0)): 9,
#  ('lizaminnelli', np.float64(1.0)): 1,
#  ('upcom', np.float64(1.0)): 2,
#  ('uk', np.float64(1.0)): 4,
#  ('😄', np.float64(1.0)): 3,
#  ('singl', np.float64(1.0)): 4,
#  ('hill', np.float64(1.0)): 4,
#  ('everi', np.float64(1.0)): 23,
#  ('beat', np.float64(1.0)): 7,
#  ('wrong', np.float64(1.0)): 9,
#  ('readi', np.float64(1.0)): 22,
#  ('natur', np.float64(1.0)): 1,
#  ('pefumeri', np.float64(1.0)): 1,
#  ('workshop', np.float64(1.0)): 2,
#  ('neal', np.float64(1.0)): 1,
#  ('yard', np.float64(1.0)): 1,
#  ('covent', np.float64(1.0)): 1,
#  ('tomorrow', np.float64(1.0)): 31,
#  ('fback', np.float64(1.0)): 26,
#  ('indo', np.float64(1.0)): 1,
#  ('harmo', np.float64(1.0)): 1,
#  ('americano', np.float64(1.0)): 1,
#  ('rememb', np.float64(1.0)): 9,
#  ('aww', np.float64(1.0)): 8,
#  ('head', np.float64(1.0)): 12,
#  ('saw', np.float64(1.0)): 16,
#  ('dark', np.float64(1.0)): 5,
#  ('handshom', np.float64(1.0)): 1,
#  ('juga', np.float64(1.0)): 1,
#  ('hurray', np.float64(1.0)): 1,
#  ...}

# %% [markdown]
# ### Pipeline para la creación de la función  `train_naive_bayes`
# Dado un diccionario de frecuencias, `train_x` (una lista de tweets) y un` train_y` (una lista de etiquetas para cada tweet), implementaremos un clasificador Naive Bayes.
#
# ##### 1.- Calcular $V$
# - Podemos calcular el número de palabras únicas que aparecen en el diccionario `freqs` para obtener $ V $ (usando la función` set`).
#
# ##### 2.- Calcular $freq_{pos}$ y $freq_{neg}$
# - Usando el diccionario `freqs`, se puede calcular la frecuencia positiva y negativa de cada palabra $ freq_ {pos} $ y $ freq_ {neg} $.
#
# ##### 3.- Calcular $N_{pos}$ y $N_{neg}$
# - Usando el diccionario `freqs`, también puede calcular el número total de palabras positivas y el número total de palabras negativas $ N_ {pos} $ y $ N_ {neg} $.
#
# ##### 4.- Calcular $D$, $D_{pos}$, $D_{neg}$
# - Usando la lista de etiquetas de entrada `train_y`, calcularemos el número de documentos (tweets) $ D $, así como el número de documentos positivos (tweets) $ D_ {pos} $ y el número de documentos negativos (tweets) $ D_ { neg} $.
# - Calcularemos la probabilidad de que un documento (tweet) sea positivo $ P (D_ {pos}) $, y la probabilidad de que un documento (tweet) sea negativo $ P (D_ {neg}) $
#
# ##### 5.- Calcularemos el logprior
# -  $log(D_{pos}) - log(D_{neg})$
#
# ##### 6.- Calculate log likelihood
# - Finalmente, iteramos sobre cada palabra en el vocabulario, usaremos la función `lookup` para obtener las frecuencias positivas, $ freq_ {pos} $, y las frecuencias negativas, $ freq_ {neg} $, para esa palabra específica.
# - Calcularemos la probabilidad positiva de cada palabra $ P (W_ {pos}) $, la probabilidad negativa de cada palabra $ P (W_ {neg}) $ usando las ecuaciones 4 y 5.
#
# $$ P(W_{pos}) = \frac{freq_{pos} + 1}{N_{pos} + V}\tag{4} $$
# $$ P(W_{neg}) = \frac{freq_{neg} + 1}{N_{neg} + V}\tag{5} $$
#
# **Nota:** Usaremos un diccionario para almacenar los loglikelihoods de cada palabra. La clave será la palabra, el valor será la probabilidad logarítmica de esa palabra).
#
# - se puede calcular la loglikelihood: $log \left( \frac{P(W_{pos})}{P(W_{neg})} \right)\tag{6}$.

# %%
def train_naive_bayes(freqs, train_x, train_y):
    loglikelihood = {} #Lambdas
    logprior = 0

    #Calcular V, el número de palabras únicas en el vocabulario
    vocab = set([pair[0] for pair in freqs.keys()])
    V = len(vocab)

    #Calculamos N_pos, N_neg
    N_pos = N_neg = 0
    for pair in freqs.keys():
        if pair[1] > 0:
            N_pos += freqs[pair]
        else:
            N_neg += freqs[pair]


    #Calcular D, el número de tweets en el conjunto de entrenamiento o corpus
    D = len(train_y)

    #Calcular D_pos, D_neg. Tweets positivos y negativos respectivamente
    D_pos = (len(list(filter(lambda x: x > 0, train_y))))
    D_neg = (len(list(filter(lambda x: x <= 0, train_y))))

    #Calcular logprior
    logprior = np.log(D_pos) - np.log(D_neg)
    
    for word in vocab:
        #Calcular la frecuencia de la palabra en los tweets positivos y negativos
        freq_pos = lookup(freqs, (word, 1), 0)
        freq_neg = lookup(freqs, (word, 0), 0)

        #Calcular loglikelihood
        p_w_pos = (freq_pos + 1) / (N_pos + V)
        p_w_neg = (freq_neg + 1) / (N_neg + V)

        #Calcular loglikelihood de cada palabra y añadirlo al diccionario loglikelihood
        loglikelihood[word] = np.log(p_w_pos / p_w_neg)


    return logprior, loglikelihood

# %%
#Entrenar al modelo con freas, train_x, train_y
logprior, loglikelihood = train_naive_bayes(freqs, train_x, train_y)

# %%
logprior
# Out:
# np.float64(0.0)

# %%
loglikelihood
# Out:
# {'bonu': np.float64(0.0019376313611963324),
#  'ctto': np.float64(0.0019376313611963324),
#  '10:59': np.float64(0.0019376313611963324),
#  'uy': np.float64(0.0019376313611963324),
#  'ceo': np.float64(0.0019376313611963324),
#  'tempor': np.float64(0.0019376313611963324),
#  'yeeeah': np.float64(0.0019376313611963324),
#  'super-blend': np.float64(0.0019376313611963324),
#  '9am': np.float64(0.0019376313611963324),
#  'beanatividad': np.float64(0.0019376313611963324),
#  '😍': np.float64(0.0019376313611963324),
#  'block': np.float64(0.0019376313611963324),
#  '1month': np.float64(0.0019376313611963324),
#  'coca': np.float64(0.0019376313611963324),
#  'mmm': np.float64(0.0019376313611963324),
#  'dammit': np.float64(0.0019376313611963324),
#  'ourdisneyinfin': np.float64(0.0019376313611963324),
#  'vibrat': np.float64(0.0019376313611963324),
#  'ughh': np.float64(0.0019376313611963324),
#  'idiot': np.float64(0.0019376313611963324),
#  'kami': np.float64(0.0019376313611963324),
#  'noo': np.float64(0.0019376313611963324),
#  'irresist': np.float64(0.0019376313611963324),
#  'shirt': np.float64(0.0019376313611963324),
#  'tax': np.float64(0.0019376313611963324),
#  'fank': np.float64(0.0019376313611963324),
#  'propa': np.float64(0.0019376313611963324),
#  'baechyyi': np.float64(0.0019376313611963324),
#  'charismat': np.float64(0.0019376313611963324),
#  'contrast': np.float64(0.0019376313611963324),
#  "sunny'": np.float64(0.0019376313611963324),
#  'ripsandrabland': np.float64(0.0019376313611963324),
#  '＠': np.float64(0.0019376313611963324),
#  'rapist': np.float64(0.0019376313611963324),
#  'discrimin': np.float64(0.0019376313611963324),
#  'strong': np.float64(0.0019376313611963324),
#  'zant': np.float64(0.0019376313611963324),
#  'insomnia': np.float64(0.0019376313611963324),
#  'syawal': np.float64(0.0019376313611963324),
#  'unlik': np.float64(0.0019376313611963324),
#  '2ban': np.float64(0.0019376313611963324),
#  'surviv': np.float64(0.0019376313611963324),
#  'india': np.float64(0.0019376313611963324),
#  'pillar': np.float64(0.0019376313611963324),
#  'canario': np.float64(0.0019376313611963324),
#  'mne': np.float64(0.0019376313611963324),
#  'weird': np.float64(0.0019376313611963324),
#  '😅': np.float64(0.0019376313611963324),
#  'scottish': np.float64(0.0019376313611963324),
#  'booor': np.float64(0.0019376313611963324),
#  'carrot': np.float64(0.0019376313611963324),
#  'phase': np.float64(0.0019376313611963324),
#  'kandekj': np.float64(0.0019376313611963324),
#  'chew': np.float64(0.0019376313611963324),
#  'reaalli': np.float64(0.0019376313611963324),
#  'fandango': np.float64(0.0019376313611963324),
#  'prepaid': np.float64(0.0019376313611963324),
#  'gta': np.float64(0.0019376313611963324),
#  'vianey': np.float64(0.0019376313611963324),
#  'lansi': np.float64(0.0019376313611963324),
#  'doh': np.float64(0.0019376313611963324),
#  'chanel': np.float64(0.0019376313611963324),
#  'notic': np.float64(0.0019376313611963324),
#  'btw': np.float64(0.0019376313611963324),
#  'jim': np.float64(0.0019376313611963324),
#  'christen': np.float64(0.0019376313611963324),
#  'm5m6junction': np.float64(0.0019376313611963324),
#  'embrac': np.float64(0.0019376313611963324),
#  'wru': np.float64(0.0019376313611963324),
#  'throat': np.float64(0.0019376313611963324),
#  'photograph': np.float64(0.0019376313611963324),
#  'postcod': np.float64(0.0019376313611963324),
#  'insan': np.float64(0.0019376313611963324),
#  'venu': np.float64(0.0019376313611963324),
#  'amen': np.float64(0.0019376313611963324),
#  'aisyhhh': np.float64(0.0019376313611963324),
#  'salmon': np.float64(0.0019376313611963324),
#  'sth': np.float64(0.0019376313611963324),
#  'empti': np.float64(0.0019376313611963324),
#  'applic': np.float64(0.0019376313611963324),
#  'exo': np.float64(0.0019376313611963324),
#  'isp': np.float64(0.0019376313611963324),
#  'addmeonsnapchat': np.float64(0.0019376313611963324),
#  'celebr': np.float64(0.0019376313611963324),
#  'non': np.float64(0.0019376313611963324),
#  'speech': np.float64(0.0019376313611963324),
#  'cauliflow': np.float64(0.0019376313611963324),
#  'gee': np.float64(0.0019376313611963324),
#  'ring': np.float64(0.0019376313611963324),
#  'sprit': np.float64(0.0019376313611963324),
#  'learnt': np.float64(0.0019376313611963324),
#  'majhwar': np.float64(0.0019376313611963324),
#  'similar': np.float64(0.0019376313611963324),
#  'friendli': np.float64(0.0019376313611963324),
#  'river': np.float64(0.0019376313611963324),
#  'digitalmarket': np.float64(0.0019376313611963324),
#  'bu': np.float64(0.0019376313611963324),
#  'sulk': np.float64(0.0019376313611963324),
#  'beaut': np.float64(0.0019376313611963324),
#  'dream': np.float64(0.0019376313611963324),
#  'logic': np.float64(0.0019376313611963324),
#  'might': np.float64(0.0019376313611963324),
#  'cyber': np.float64(0.0019376313611963324),
#  'pup': np.float64(0.0019376313611963324),
#  'ganna': np.float64(0.0019376313611963324),
#  'ay': np.float64(0.0019376313611963324),
#  'gahhh': np.float64(0.0019376313611963324),
#  'sin': np.float64(0.0019376313611963324),
#  '>:d': np.float64(0.0019376313611963324),
#  'huh': np.float64(0.0019376313611963324),
#  'inatal': np.float64(0.0019376313611963324),
#  'downstair': np.float64(0.0019376313611963324),
#  'slow': np.float64(0.0019376313611963324),
#  'hell': np.float64(0.0019376313611963324),
#  's02e04': np.float64(0.0019376313611963324),
#  'friyay': np.float64(0.0019376313611963324),
#  'earthl': np.float64(0.0019376313611963324),
#  ...}

# %%
len(loglikelihood)
# Out:
# 9067

# %% [markdown]
# # Probando el modelo de Naive Bayes
#
# Ahora que tenemos `logprior` y` loglikelihood`, podemos probar el modelo de Naive Bayes para predecir algunos tweets.
#
# #### Implementación de  `naive_bayes_predict`
#
# Implementaremos la función `naive_bayes_predict` para hacer predicciones de tweets.
#
# * La función toma como entrada el `tweet`,` logprior`, y `loglikelihood`.
# * Devuelve la probabilidad de que el tweet pertenezca a la clase positiva o negativa.
# * Para cada tweet, se sumarán las probabilidades de cada palabra en el tweet.
# * También se agregará el logprior de esta suma para obtener la predicción de sentimiento del tweet
#
# $$ p = logprior + \sum_i^N (loglikelihood_i)$$
#
# #### Nota
#
# Tenga en cuenta que calculamos el "prior" a partir de los datos de entrenamiento y que los datos de entrenamiento se dividen uniformemente entre etiquetas positivas y negativas (4000 tweets positivos y 4000 negativos). Esto significa que el ratio de positivo a negativo 1, y el logprior es 0.
#
# El valor de 0.0 significa que cuando agregamos el logprior al likelihood, simplemente estamos agregando un valor de cero a la probabilidad logarítmica. Sin embargo, recuerde incluir el logprior, porque siempre que los datos no estén perfectamente equilibrados, el logprior será un valor distinto de cero.

# %%
def naive_bayes_predict(tweet, logprior, loglikelihood):
    word_l = process_tweet(tweet)
    p = 0
    p += logprior
    for word in word_l:
        if word in loglikelihood:
            p += loglikelihood[word]

    return p

# %%
# Probar el modelo con un tweet
my_tweet = 'I feel ok today'
p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
print(p)
# Out:
# 0.005812894083588998

# %% [markdown]
# #### Implementando  test_naive_bayes
#
# * Implementaremos `test_naive_bayes` la función para ver el accuracy de las predicciones.
# * La función toma de `test_x`, `test_y`,el log_prior, y el loglikelihood
# * Regresa el ccuracy del modelo
# * Primeramente, usaremos la función `naive_bayes_predict` para hacer las predicciones para cada tweet en text_x.

# %%
def test_naive_bayes(test_x, test_y, logprior, loglikelihood):
   
    accuracy = 0 
    y_hats = []
    for tweet in test_x:
        if naive_bayes_predict(tweet, logprior, loglikelihood) > 0:
            y_hat_i = 1
        else:
            y_hat_i = 0
        y_hats.append(y_hat_i)

    error = np.mean(np.absolute(y_hats-test_y))
    accuracy = 1-error

    return accuracy

# %%
#Test naive bayes
test_naive_bayes(test_x, test_y, logprior, loglikelihood)
# Out:
# np.float64(0.499)

# %%
# Test tweets
lista_tweets = ['I am happy', 'I am bad', 'this movie should have been great.', 'great', 'great great', 'great great great', 'great great great great']

for tweet in lista_tweets:
    p = naive_bayes_predict(tweet, logprior, loglikelihood)
    print(f'{p:.8f} -> {tweet}')
# Out:
# 0.00193763 -> I am happy
# 0.00193763 -> I am bad
# 0.00387526 -> this movie should have been great.
# 0.00193763 -> great
# 0.00387526 -> great great
# 0.00581289 -> great great great
# 0.00775053 -> great great great great

# %% [markdown]
# ### Predecir un tweet propio

# %%
my_tweet = 'you are bad :('
naive_bayes_predict(my_tweet, logprior, loglikelihood)
# Out:
# np.float64(0.0038752627223926648)

# %% [markdown]
# # Filtrado de palabras por ratios positivos y negativos
#
# - Algunas palabras tienen un conteo de etiquetas más positivos que otras y pueden considerarse "más positivas". Asimismo, algunas palabras pueden considerarse más negativas que otras.
#
# - Una forma de definir el nivel de positividad o negatividad, sin calcular la probabilidad logarítmica, es comparar la frecuencia positiva con la negativa de la palabra.
#
#     - Tenga en cuenta que también podemos utilizar los cálculos de probabilidad logarítmica para comparar la positividad o negatividad relativa de las palabras.
#
# - Podemos calcular el ratio de las frecuencias positivas y negativas de una palabra.
# - Una vez que podamos calcular estos ratios, también podemos filtrar un subconjunto de palabras que tengan una proporción mínima de positividad / negatividad o superior.
# - De manera similar, también podemos filtrar un subconjunto de palabras que tienen una proporción máxima de positividad / negatividad o menor (palabras que son menos negativas, o incluso más negativas que un umbral dado).
#
# #### Implementación `get_ratio()`
#
# - Dado el diccionario de palabras `freqs` y una palabra en particular, usaremos` lookup (freqs, word, 1) `para obtener el recuento positivo de la palabra.
# - De manera similar, usaremos la función `lookup ()` para obtener el recuento negativo de esa palabra.
# - Calcularemos la proporción de positivo dividido por conteos negativos.
#
# $$ ratio = \frac{pos_{words} + 1}{neg_{words} + 1} $$
#
# donde pos_words y neg_words corresponden a la frecuencia de las palabras en su respectiva clase.
# <table>
#     <tr>
#         <td>
#             <b>Words</b>
#         </td>
#         <td>
#         Positive word count
#         </td>
#          <td>
#         Negative Word Count
#         </td>
#   </tr>
#     <tr>
#         <td>
#         glad
#         </td>
#          <td>
#         41
#         </td>
#     <td>
#         2
#         </td>
#   </tr>
#     <tr>
#         <td>
#         arriv
#         </td>
#          <td>
#         57
#         </td>
#     <td>
#         4
#         </td>
#   </tr>
#     <tr>
#         <td>
#         :(
#         </td>
#          <td>
#         1
#         </td>
#     <td>
#         3663
#         </td>
#   </tr>
#     <tr>
#         <td>
#         :-(
#         </td>
#          <td>
#         0
#         </td>
#     <td>
#         378
#         </td>
#   </tr>
# </table>

# %%
def get_ratio(freqs, word):
    pos_neg_ratio = {'positivo':0, 'negativo':1, 'ratio':0.0}

    pos_neg_ratio['positivo'] = lookup(freqs, word, 1)
    pos_neg_ratio['negativo'] = lookup(freqs, word, 0)
    pos_neg_ratio['ratio'] = (pos_neg_ratio['positivo'] + 1) / (pos_neg_ratio['negativo'] + 1)

    return pos_neg_ratio

# %%
get_ratio(freqs, 'happi')
# Out:
# {'positivo': 161, 'negativo': 18, 'ratio': 8.526315789473685}

# %% [markdown]
# #### Implementación `get_words_by_threshold(freqs,label,threshold)`
#
# * Si establecemos label en 1, buscaremos todas las palabras cuyo umbral de positivo / negativo sea mayoy o igual al umbral.
# * Si establecemos la etiqueta en 0, buscaremos todas las palabras cuyo umbral de positivo / negativo sea menor o igual al umbral.
# * Utilizaremos la función `get_ratio ()` para obtener un diccionario que contenga el recuento positivo, el recuento negativo y la proporción de recuentos positivos y negativos.
# * Agregaremos un diccionario a una lista, donde la clave es la palabra y el diccionario es el diccionario `pos_neg_ratio` que es devuelto por la función` get_ratio () `.
#
# Un ejemplo de este diccionario sería:
# ```
# {'happi':
#     {'positive': 10, 'negative': 20, 'ratio': 0.5}
# }
# ```

# %%
def get_words_by_threshold(freqs, label, threshold):
    word_list = {}
    for key in freqs.keys():
        word, _ = key
        # Obtenemos los ratios positivos y negativos
        pos_neg_ratio = get_ratio(freqs, word)

        # Si la etiqueta es 1 y el ratio en mayor o igual a el threshold
        if label == 1 and pos_neg_ratio['ratio'] >= threshold:
            # Añadimos el valor del pos_neg_ratio al diccionario
            word_list[word] = pos_neg_ratio

        # Si la etiqueta es 0 y el pos_neg_ratio es menor igual que el threshold entonces
        elif label == 0 and pos_neg_ratio['ratio'] <= threshold:
            # Añadimos el valor del pos_neg_ratio al diccionario
            word_list[word] = pos_neg_ratio

    return word_list

# %%
# Probar la función. Encontrar palabras negativas por debajo de un threshold 
get_words_by_threshold(freqs, label=0, threshold=0.05)
# Out:
# {':(': {'positivo': 1, 'negativo': 3663, 'ratio': 0.0005458515283842794},
#  ':-(': {'positivo': 0, 'negativo': 378, 'ratio': 0.002638522427440633},
#  'zayniscomingbackonjuli': {'positivo': 0, 'negativo': 19, 'ratio': 0.05},
#  '26': {'positivo': 0, 'negativo': 20, 'ratio': 0.047619047619047616},
#  '>:(': {'positivo': 0, 'negativo': 43, 'ratio': 0.022727272727272728},
#  'lost': {'positivo': 0, 'negativo': 19, 'ratio': 0.05},
#  '♛': {'positivo': 0, 'negativo': 210, 'ratio': 0.004739336492890996},
#  '》': {'positivo': 0, 'negativo': 210, 'ratio': 0.004739336492890996},
#  'beli̇ev': {'positivo': 0, 'negativo': 35, 'ratio': 0.027777777777777776},
#  'wi̇ll': {'positivo': 0, 'negativo': 35, 'ratio': 0.027777777777777776},
#  'justi̇n': {'positivo': 0, 'negativo': 35, 'ratio': 0.027777777777777776},
#  'ｓｅｅ': {'positivo': 0, 'negativo': 35, 'ratio': 0.027777777777777776},
#  'ｍｅ': {'positivo': 0, 'negativo': 35, 'ratio': 0.027777777777777776}}

# %%
# # Probar la función. Encontrar palabras positivas por arriba de un threshold 
get_words_by_threshold(freqs, label=1, threshold=10)
# Out:
# {'followfriday': {'positivo': 23, 'negativo': 0, 'ratio': 24.0},
#  'commun': {'positivo': 27, 'negativo': 1, 'ratio': 14.0},
#  ':)': {'positivo': 2847, 'negativo': 2, 'ratio': 949.3333333333334},
#  'flipkartfashionfriday': {'positivo': 16, 'negativo': 0, 'ratio': 17.0},
#  ':d': {'positivo': 498, 'negativo': 0, 'ratio': 499.0},
#  ':p': {'positivo': 104, 'negativo': 0, 'ratio': 105.0},
#  'influenc': {'positivo': 16, 'negativo': 0, 'ratio': 17.0},
#  ':-)': {'positivo': 543, 'negativo': 0, 'ratio': 544.0},
#  "here'": {'positivo': 20, 'negativo': 0, 'ratio': 21.0},
#  'youth': {'positivo': 14, 'negativo': 0, 'ratio': 15.0},
#  'bam': {'positivo': 44, 'negativo': 0, 'ratio': 45.0},
#  'warsaw': {'positivo': 44, 'negativo': 0, 'ratio': 45.0},
#  'shout': {'positivo': 11, 'negativo': 0, 'ratio': 12.0},
#  ';)': {'positivo': 22, 'negativo': 0, 'ratio': 23.0},
#  'stat': {'positivo': 51, 'negativo': 0, 'ratio': 52.0},
#  'arriv': {'positivo': 57, 'negativo': 4, 'ratio': 11.6},
#  'via': {'positivo': 60, 'negativo': 1, 'ratio': 30.5},
#  'glad': {'positivo': 41, 'negativo': 2, 'ratio': 14.0},
#  'blog': {'positivo': 27, 'negativo': 0, 'ratio': 28.0},
#  'fav': {'positivo': 11, 'negativo': 0, 'ratio': 12.0},
#  'fback': {'positivo': 26, 'negativo': 0, 'ratio': 27.0},
#  'pleasur': {'positivo': 10, 'negativo': 0, 'ratio': 11.0}}

# %% [markdown]
# **Observe la diferencia entre los ratios positivos y negativos. Emojis como :( y palabras como 'me' tienden a tener una connotación negativa. Otras palabras como 'glad', 'comunity' y 'arrives' tienden a encontrarse en los tw-eets positivos.**

# %% [markdown]
# ### Análisis de Error
#
# En esta parte, veremos algunos tweets que el modelo no clasificó correctamente.

# %%
print('Tweets predecidos en la clase Positivo')
for x, y in zip(test_x, test_y):
    y_hat = naive_bayes_predict(x, logprior, loglikelihood)
    if y != (np.sign(y_hat) > 0):
        print('%d\t%0.2f\t%s' % (y, np.sign(y_hat) > 0, ' '.join(
            process_tweet(x)).encode('ascii', 'ignore')))
# Out:
# Tweets predecidos en la clase Positivo
# 1	0.00	b''
# 1	0.00	b''
# 1	0.00	b''
# 0	1.00	b'help ... stop cri :('
# 0	1.00	b'otl nevermind :( least got jeon'
# 0	1.00	b'soon tweet plant claw thigh traction zoom away :('
# 0	1.00	b'damnit :('
# 0	1.00	b'use pri pv ... wish could reliv day becom nyc pv buy way commun nyc usa klm :('
# 0	1.00	b'realli hot :-('
# 0	1.00	b'monday :('
# 0	1.00	b"go stop breakfast earli might want remov 11am websit even mcd' pull trick :("
# 0	1.00	b'mean way :( 3rd load hung'
# 0	1.00	b':( wtf suppos without'
# 0	1.00	b'headach strike :('
# 0	1.00	b'english weather need fix :('
# 0	1.00	b'live fam bam cough :('
# 0	1.00	b'absolut gut jame bay ticket sold manchest :('
# 0	1.00	b'seventh spot na lang :( otwolgrandtrail'
# 0	1.00	b'splendour :('
# 0	1.00	b'omg swedish hair metal legend hirfrc studio leav nooo :( givecodpieceach'
# 0	1.00	b'sore alic :('
# 0	1.00	b'readi work yet :('
# 0	1.00	b'someon unfav :('
# 0	1.00	b'stile :('
# 0	1.00	b'funni mo :('
# 0	1.00	b'someon explain sandrabland :('
# 0	1.00	b'dont sad :( ili'
# 0	1.00	b'go spend night pragu leav tomorrow :('
# 0	1.00	b'one friend follow littl heart attack im sorri your block :( sadi'
# 0	1.00	b'annoy :('
# 0	1.00	b'consid lucki favourit charact even make season final 100 :('
# 0	1.00	b'boo alreadi turn ye 915 :('
# 0	1.00	b'itun wait notanapolog :('
# 0	1.00	b'layout match closest could find header :( someon help'
# 0	1.00	b"hayee :( hayee :( patwari mam ik' vision would say noth rather lil laugh"
# 0	1.00	b'agh sorri :-('
# 0	1.00	b'vidcon :( :( :('
# 0	1.00	b'ga :('
# 0	1.00	b'awhhh ok ok :( see nalang class open hehe'
# 0	1.00	b'last night one worst night :( pretti sure albanian women curs'
# 0	1.00	b'air max tava pl pl pl pl :('
# 0	1.00	b'taken :( anoth chara mayb teteh'
# 0	1.00	b'dev verri sad caus twitter :('
# 0	1.00	b'imagin would shatter dream :-( let colleagu know sb'
# 0	1.00	b'much miss :('
# 0	1.00	b'nawe :('
# 0	1.00	b'want white french bulldog :('
# 0	1.00	b'wanna feel love :('
# 0	1.00	b"aww poor wish help even though can't realli help much :("
# 0	1.00	b'sorri see tweet :( 2 point x'
# 0	1.00	b'miss macho man :('
# 0	1.00	b'hav puriti back :('
# 0	1.00	b'kwento :( fbc'
# 0	1.00	b'3 day without talk bae :('
# 0	1.00	b'whaaat nooo :('
# 0	1.00	b'pleas tweet someth sad :( cheer pleas ..'
# 0	1.00	b'miss brown hair :('
# 0	1.00	b'nakakapikon yung nagbabasa ka ng blog comment info full peopl ask damn question answer post :('
# 0	1.00	b'lead caus cancer children five :('
# 0	1.00	b"alon :-( :'( :-\\"
# 0	1.00	b'hello info possibl interest jonatha close join beti :( great'
# 0	1.00	b'sorri peopl shit respect person space :('
# 0	1.00	b'nooo :( sogok ice cream'
# 0	1.00	b'thank send premium write instrument howev dastardli swine stole envelop :('
# 0	1.00	b'im get sick tire pipol say im short ... short ... tini :('
# 0	1.00	b'fair enough :( would anyon seem tad fuck  .. wiper wiper'
# 0	1.00	b'supposedli one worst kernel devic :('
# 0	1.00	b'bore :('
# 0	1.00	b'true doubt :( zayniscomingbackonjuli 26'
# 0	1.00	b'today  job anoth fack intel extra mega care get bent socket pin :-( pcgame pcupgrad'
# 0	1.00	b'hate messeng :('
# 0	1.00	b'everyon asleep alreadi :('
# 0	1.00	b'brainwash :('
# 0	1.00	b'1 pl download smosh movi free onlin hahahaha :('
# 0	1.00	b'kik plawnew 837 kik kikmenow amateur sf snapm summer hotti :('
# 0	1.00	b'omg way guy aswel :-( btw cat litter isnt good pregnanc make sure u dont go near'
# 0	1.00	b'ah mensch :('
# 0	1.00	b'sepanx one :('
# 0	1.00	b'cannot view pictur unhappi seat bu :('
# 0	1.00	b"there' huge bag present luke can't open back work :-("
# 0	1.00	b'pci mine :-('
# 0	1.00	b'last time went caerphilli find anywher sell local chees :-('
# 0	1.00	b'eye realli bad today even glass :('
# 0	1.00	b'omw  lol wish :('
# 0	1.00	b'joke lang eh :( hahdhdhshh'
# 0	1.00	b'never see dad midnight bc work hard fuck :( growinguppoor'
# 0	1.00	b'number one america   wish could buy money :('
# 0	1.00	b"wish buy bangtan' merch :("
# 0	1.00	b'pain ubericecream driver busi :('
# 0	1.00	b'oh gosh say aw hun :( cuddl'
# 0	1.00	b'want :('
# 0	1.00	b'taimoor meray dost :('
# 0	1.00	b'tya mind refollow :('
# 0	1.00	b'stomach kill :('
# 0	1.00	b'apolog avail australia :('
# 0	1.00	b'ksoo u dumb butt :('
# 0	1.00	b'omg get hate sex offend :( poor :( stupid pissbabi'
# 0	1.00	b'want finish death parad weekend :('
# 0	1.00	b'frustrat plank time super inconsist idea wrong :('
# 0	1.00	b'rip tom moor ... love read comic book ... anoth great artist truli miss :('
# 0	1.00	b'miss much :('
# 0	1.00	b'awww miss swear twitter day truli bore rather watch movi footbal :('
# 0	1.00	b'sch get better ... :-('
# 0	1.00	b'throat sore :('
# 0	1.00	b'one awak :('
# 0	1.00	b'im hungri :('
# 0	1.00	b'get bin osx chrome voiceov >:('
# 0	1.00	b'  night :( devo xxx'
# 0	1.00	b'im sad :('
# 0	1.00	b'hope wrong hulkhogan think know deep hurt wake kind unpleas :('
# 0	1.00	b'even know say :('
# 0	1.00	b'daaamn :('
# 0	1.00	b'grabe ang harsh huhuhu u like :('
# 0	1.00	b'aw babe :('
# 0	1.00	b'boy r play :( cant watch :( rip'
# 0	1.00	b'dada uh iphon na :( :( pic '
# 0	1.00	b'sorri fulli book :-( xx'
# 0	1.00	b'unfollow unni :('
# 0	1.00	b'lucki spike :-('
# 0	1.00	b'omg miss 2 :('
# 0	1.00	b"panic' new album come 22nd :("
# 0	1.00	b'bigbang need rest :( travel one place anoth must realli tire :('
# 0	1.00	b':( rude'
# 0	1.00	b'mention south africa mani time song time come south africa :('
# 0	1.00	b"hate can't rememb dream love share :("
# 0	1.00	b'go america man r p victim louisiana :('
# 0	1.00	b'school come twitter :('
# 0	1.00	b'take 190 horribl time :('
# 0	1.00	b'ella :( cheer pl'
# 0	1.00	b"that' excus launch attack lizardz feel like shit deepli asham >:("
# 0	1.00	b'noth wors :('
# 0	1.00	b'sorri :( need get emerg engin home next 4 hour laura'
# 0	1.00	b'never go sleep earli :( lol'
# 0	1.00	b'home dormtel near st scho girl siya tho :( want help find onee'
# 0	1.00	b'talk exclus :( u know carri u want play '
# 0	1.00	b'7pm friday dead :('
# 0	1.00	b'sorri nat school holiday .. :( work 1pm'
# 0	1.00	b'im work :('
# 0	1.00	b'everi time feta chees head start blaaaz sometim vision mess nausea come :('
# 0	1.00	b"oh that' good :( awar issu abl top-up"
# 0	1.00	b'sharknado one hour never get back :('
# 0	1.00	b'yeah leav read :-('
# 0	1.00	b'cannot even sleep right :('
# 0	1.00	b'erni :('
# 0	1.00	b'tl :( hungri af'
# 0	1.00	b'rain :-('
# 0	1.00	b'ezoo year sorri :-('
# 0	1.00	b'look fun snapchat lilybutl 18 snapchat kikmenow amateur kikmeboy seduc hannib kiksext :('
# 0	1.00	b'ed sheeran preform countri tonight ur go :('
# 0	1.00	b'cannot seem get one powai :('
# 0	1.00	b'neighbor let sleep :-('
# 0	1.00	b'back delhi :('
# 0	1.00	b'feet cold point take sock okay stop :('
# 0	1.00	b"can't belieb rain :("
# 0	1.00	b"sinc model stop stock boot can't get can't even order onlin tell unsaf :("
# 0	1.00	b'summer holiday great bore alreadi :('
# 0	1.00	b'oh plan stream halo xbox one today :('
# 0	1.00	b'drop dead fred use favorit movi wish :-('
# 0	1.00	b"rememb 2 gaon bad 6 infnt elig apink :( acub why'd u"
# 0	1.00	b'sad everi time apink event .. understand korean :(  '
# 0	1.00	b':( fun'
# 0	1.00	b'bullshit ... :('
# 0	1.00	b':( know happen internet light connect drop thank kei'
# 0	1.00	b'wish could hear food :('
# 0	1.00	b'hanaaa birthday ya allah sorri wish van jn tak tau :( happi birthday gorgeou'
# 0	1.00	b'omg realli sorri babe :('
# 0	1.00	b'happen soul si :('
# 0	1.00	b'faith :('
# 0	1.00	b'last present receiv  haha basta :('
# 0	1.00	b'went bed headach ... woke headach :('
# 0	1.00	b'snapchat guy jasmingarrick snapchat kiksext chat sext addm mpoint hotmusicdeloco :('
# 0	1.00	b'relat full lie :('
# 0	1.00	b"aw fuck there' dress bag floor dammit that' realli loud :("
# 0	1.00	b'dhi  block twitter :( thank good time  play 8ball fakmarey'
# 0	1.00	b'unfortun smell like doo doo :('
# 0	1.00	b'wanna go six flag :('
# 0	1.00	b'sorri :('
# 0	1.00	b'shop fun :('
# 0	1.00	b'miss cat :('
# 0	1.00	b'miss :('
# 0	1.00	b'would like abl work full time stuff move consid take fulltim job :('
# 0	1.00	b'yeah seen someth tinder fb root :( woman frustrat awkward'
# 0	1.00	b'food kitchen money wallet thank barcelona dad home month beet juic either :('
# 0	1.00	b'dci today wish go :-('
# 0	1.00	b'work freez :('
# 0	1.00	b'srsli u :('
# 0	1.00	b'hate see granddad like :('
# 0	1.00	b'sorri pre :('
# 0	1.00	b'want minion bucket pleas :( yesterday :('
# 0	1.00	b'fair love war kapan updat :( oh ya udah dihapu hilang dari muka bumi want read someon give link '
# 0	1.00	b'girl quick :('
# 0	1.00	b'mani nasti narrow mind peopl :('
# 0	1.00	b'want room :-('
# 0	1.00	b'friend respect life :-( sorri'
# 0	1.00	b'sadli :('
# 0	1.00	b'suck gona miss chello parti :('
# 0	1.00	b'hello info possibl interest jonatha close join beti :('
# 0	1.00	b"can't watch phone sorri :( thank still <3"
# 0	1.00	b'taxi driver thought sophi work nintendo took us gate :( secur guard gave us dirtiest look haha'
# 0	1.00	b'omg :-( love much monica see soon aaahhh'
# 0	1.00	b':( crepe 40 '
# 0	1.00	b'kick bae :('
# 0	1.00	b'haha sound like  fun game :('
# 0	1.00	b'follow :('
# 0	1.00	b'school monday wanna meet new peopl :('
# 0	1.00	b'... havent finish yet :('
# 0	1.00	b'u forsaken ran gf :('
# 0	1.00	b'kanin pleas :( xd'
# 0	1.00	b'get hypixel :( want record grrr thestruggleisr geek gamer gamer youtub'
# 0	1.00	b'want afterbirth :('
# 0	1.00	b"bummer :( apink' digit physic sale super great bc time album releas win"
# 0	1.00	b'overperhatian :( :('
# 0	1.00	b'sad :('
# 0	1.00	b"that' aw :( son miss physic exam chicken pox gave predict grade poor girl"
# 0	1.00	b'srsli tho bae look :('
# 0	1.00	b'ahm ... never london ... holiday outsid ireland nearli 8 year :( never got chanc cash go'
# 0	1.00	b'pleas follow :('
# 0	1.00	b'omg :-('
# 0	1.00	b'5am wit ha damn headach :('
# 0	1.00	b'dream met karli kloss sweet want take like bunch goofi photo :('
# 0	1.00	b'realiz 3 watch concert video pcd extrem hard rn :('
# 0	1.00	b'sorri antagonis call writer sever polit nudg ... :('
# 0	1.00	b'delv enough seen heard fuck horrend :('
# 0	1.00	b'follow :('
# 0	1.00	b'duo drop doubl digit :( twice'
# 0	1.00	b'got :( come'
# 0	1.00	b'theyr cute wish knew say :('
# 0	1.00	b'care :('
# 0	1.00	b"wish could'v met :("
# 0	1.00	b'grandad realli well :( worri much'
# 0	1.00	b"u gray' followk omg hard day u know :( :("
# 0	1.00	b'idk bc money leav :-('
# 0	1.00	b'lot peopl suggest still :('
# 0	1.00	b'follback pl :('
# 0	1.00	b'get pace maker oh :('
# 0	1.00	b'ah minc :('
# 0	1.00	b'molli deserv much higher place :('
# 0	1.00	b'hungri :('
# 0	1.00	b'wanna good time one hit date much ask :('
# 0	1.00	b'feel sucki w run nose cough sore throat fever :-('
# 0	1.00	b'hate hot weather :( graduat ceremoni later boy gonna wear suit everyon go die'
# 0	1.00	b"let' go parti ... pant ew :( gross"
# 0	1.00	b'someon niall layout give :('
# 0	1.00	b'hey christin moodi :('
# 0	1.00	b'miss :('
# 0	1.00	b'throwback :('
# 0	1.00	b'that good enough reason :( pleas dont leav your one fav barb'
# 0	1.00	b'cooper convinc neither 2 pleas concern creasi win deputi :('
# 0	1.00	b'tast bad though :('
# 0	1.00	b'joke man :('
# 0	1.00	b"never remov minion car 23 day run batteri banana' :("
# 0	1.00	b'want sponsor acc new even 1k :('
# 0	1.00	b'told u guy bday today :( gift want paypal'
# 0	1.00	b'goodby stage alreadi :-('
# 0	1.00	b'shit idk time :('
# 0	1.00	b'today tire :-('
# 0	1.00	b'pretti :('
# 0	1.00	b':( matt'
# 0	1.00	b'hello info possibl interest jonatha close join beti :( saludo'
# 0	1.00	b'hey someon text :('
# 0	1.00	b'anoth dissapoint review :('
# 0	1.00	b" <-- face everi guy pull get head feel bae' teeth dick :("
# 0	1.00	b'ahhh well :('
# 0	1.00	b'wanna see paper town w :('
# 0	1.00	b'get long last black pump :('
# 0	1.00	b'omfg beauti place ever miss much :('
# 0	1.00	b'hate pimpl :('
# 0	1.00	b'almost 12 tire :('
# 0	1.00	b"honey brown sugar good ur lip :/ amount stuff use face could'v use food instead :("
# 0	1.00	b'ikr hai would someon sell preciou thing :('
# 0	1.00	b'tire :( got good sleep'
# 0	1.00	b'yea man ... suppos footbal tdi man plan fail :('
# 0	1.00	b'pleas god wanna go work :('
# 0	1.00	b'kinda miss pamela good anna :('
# 0	1.00	b"pleas woe can't run six though live mexico :("
# 0	1.00	b'idk get mini bu idk time go get :('
# 0	1.00	b'hi harri sorri :( work mast area caus intermitt servic work complet'
# 0	1.00	b'look fun snapchat janniecam snapchat kikm webcam snapchatm kikhorni musicbiz hotmusicdeloco :('
# 0	1.00	b'braxton gone pro :( feel bad urban unpreced brainwash see tebow alex smith'
# 0	1.00	b'wat okaaay huhu :( sayanggg find yah phone'
# 0	1.00	b'1 taxi servic 2 second schedul blog post 3 housework bust :('
# 0	1.00	b'mum say done leav step dad :-('
# 0	1.00	b'want go disneyland badli :-('
# 0	1.00	b'bc thoma tommyy :('
# 0	1.00	b'billi ... :('
# 0	1.00	b'fanci kevin clifton strictli come danc much marri :( whyyi'
# 0	1.00	b'nsc mat 0 tomorrow :('
# 0	1.00	b"awhh see guy would'v ram car :("
# 0	1.00	b"that' ok :( reason voucher can't use onlin"
# 0	1.00	b'kik smadvow 544 kik kikgirl lgbt photo model free hotti :('
# 0	1.00	b"everyone' work can't even get :("
# 0	1.00	b'would love see acdc .. miss ticket :('
# 0	1.00	b':( aker ive send ka gmail u get :('
# 0	1.00	b'last stage today :( go miss see almost everyday'
# 0	1.00	b'never give best thing take time weh :('
# 0	1.00	b'guy add kik sprevelink 633 kik hornykik chat porno orgasm free webcamsex :('
# 0	1.00	b'lana :('
# 0	1.00	b'miss 11:11 :( btw wish follow  loveyoutilltheendcart '
# 0	1.00	b'aw sound great better lunch :('
# 0	1.00	b'want play sfv capcom plz :('
# 0	1.00	b'tip onlin 6/7 winner yesterday 1 goal nice 20/1 :( hope similar strike rate today'
# 0	1.00	b'u prob fun david'
# 0	1.00	b'sooo burnt ... :-('
# 0	1.00	b'need new phone :('
# 0	1.00	b'miss tito daddi :('
# 0	1.00	b'rosi hayoung shut :('
# 0	1.00	b'want ram nlb :-('
# 0	1.00	b'hahahah holi shit comfort :('
# 0	1.00	b'could flat ab time ... @_ gym tayo g :('
# 0	1.00	b'yeah :('
# 0	1.00	b'first two day kati summer back forth doctor suspect mening viral tonsil :( poorli girl '
# 0	1.00	b'wanna go movi today one :('
# 0	1.00	b'want watch paper town :-('
# 0	1.00	b'repli yet :( ang given work next 3 week  x'
# 0	1.00	b'say :-('
# 0	1.00	b'babyy :('
# 0	1.00	b'dont either :( ugli cushion littl longer thank help'
# 0	1.00	b'happi birthday pleas come back singapor :-(                 '
# 0	1.00	b'weigh risk premium go :( lot money 1 reason keen get dog'
# 0	1.00	b'know feel man :('
# 0	1.00	b'yeah look :('
# 0	1.00	b"can't see say ice cream uber app :( set locat"
# 0	1.00	b'wish could see ben :('
# 0	1.00	b'think ever win petrofac cup :-( ;-)'
# 0	1.00	b"15 day ago danni took wig put onto mark' head want go back :( "
# 0	1.00	b'pathet emot burden.say like care hug respect toler call name :-('
# 0	1.00	b'allerg cat ... itchi throat :('
# 0	1.00	b'like dog :('
# 0	1.00	b'man right wish someon would bring food offic starv :('
# 0	1.00	b'gosh cheaper malaysia :( worth 130 ship'
# 0	1.00	b'weather set sleep respons :-('
# 0	1.00	b'think someon hack acc :('
# 0	1.00	b'guy nooo :-( wow wow wow wow'
# 0	1.00	b'boy snapchattimg happi bc friend ruin said wanna fun   :('
# 0	1.00	b'look 12 still :('
# 0	1.00	b'tbh forget donat manag sin due hp corrupt restor data lost lor :('
# 0	1.00	b'worst pain :('
# 0	1.00	b'never dedic anyth :( smh lol'
# 0	1.00	b'iren unni bite finger worriedli stare staff :( okay unni'
# 0	1.00	b'feel sick :('
# 0	1.00	b':('
# 0	1.00	b'guy add kik toneadi 46532 kik kikmeboy wife porno snapdirti premiostumundo sheskindahot :('
# 0	1.00	b'omfg hug corps :('
# 0	1.00	b'taeni fyeah link broken :('
# 0	1.00	b'hello info possibl interest jonatha he close beti :('
# 0	1.00	b'cant watch tonight andromeda :('
# 0	1.00	b'la time right ye yunni im seriou :('
# 0	1.00	b'develop releas good game school :('
# 0	1.00	b'thank feel aw sick long time :('
# 0	1.00	b'lot write boy section whdjwksja idk ziam write still fuck go 100k school :('
# 0	1.00	b'noo ben watch like hawk week gut :('
# 0	1.00	b'spoil :('
# 0	1.00	b'none hide behind shower curtain :('
# 0	1.00	b':( want good least watchabl account neither'
# 0	1.00	b'want watch :('
# 0	1.00	b'last day indiana :('
# 0	1.00	b'fav chees give migrin :('
# 0	1.00	b"still sad fix car window bc can't drive anywher without scare shatter :("
# 0	1.00	b'morn work unfortun :( gdce gamescom'
# 0	1.00	b'hay idk babi :(   '
# 0	1.00	b"oh :( do't think parcel come yodel hit follow dm track num chelsea"
# 0	1.00	b'wish could friend everybodi :( lmfaooo'
# 0	1.00	b'oooouch poor pinki toe  good thing work podiatrist wait morn go hurri morn :('
# 0	1.00	b'morn miss :('
# 0	1.00	b'miss old hous could hear parent door open act like asleep :('
# 0	1.00	b"gusto ko ng rodic' :( someon share order one' big"
# 0	1.00	b'adoohh :('
# 0	1.00	b'b-butt black cat bad luck ene'
# 0	1.00	b'miss ticket show morn :( get tigermilk fix'
# 0	1.00	b'ye hope next year :('
# 0	1.00	b'want meet jacob bad :('
# 0	1.00	b'pleas tell :('
# 0	1.00	b'use recommend east dulwich gone super crazi last five year :('
# 0	1.00	b'awww miss :('
# 0	1.00	b'last episod realli intens :( kagami n kuroko forev <3'
# 0	1.00	b"can't sleep :-("
# 0	1.00	b"can't say nah food :("
# 0	1.00	b'want see :( sana makita na kita ang'
# 0	1.00	b'spooki jim smol bean :('
# 0	1.00	b'one guy true blood st fagan yesterday :( :( :('
# 0	1.00	b'buy book memem live finland :('
# 0	1.00	b'whaaat fair :('
# 0	1.00	b'nooo stay uk im :('
# 0	1.00	b'aw poor thing :('
# 0	1.00	b'also want :('
# 0	1.00	b'look amaz think saw meadowhal day actual unfortun weekend work :('
# 0	1.00	b'sorri :( spend time instagram'
# 0	1.00	b'rip lola :( miss sorri di kita nadalaw last day thank everyth .. sa memori sa warm hug sa lahat labyu la'
# 0	1.00	b'oki :-('
# 0	1.00	b'dont want anyth happen bae :('
# 0	1.00	b'even start trend wanna know jot truth :( zayniscomingbackonjuli 26'
# 0	1.00	b'snapchat guy ivypowel 19 snapchat kikhorni chat girl like 4like travel phonesex :('
# 0	1.00	b'schade :('
# 0	1.00	b'missin homeslic bday :( </3 33'
# 0	1.00	b'poor throat :('
# 0	1.00	b'fav emoticon right :( emoticon'
# 0	1.00	b'see get eyebrow done prettylook wanna tri differ style :('
# 0	1.00	b'rip whitney houston :('
# 0	1.00	b'aur ap bhi shamil ho :('
# 0	1.00	b'much past 2 day bc need save 3g feel like miss tonn :('
# 0	1.00	b'hey sorri hear :( check servic statu page '
# 0	1.00	b'hold back like way :('
# 0	1.00	b'amount eat day ridicul know suddenli alway hungri :('
# 0	1.00	b'omg alli hug mani wrap arm around neck pull closer :-('
# 0	1.00	b'love toothsensit :-('
# 0	1.00	b'ye :('
# 0	1.00	b'heartbroken :('
# 0	1.00	b'chover :('
# 0	1.00	b'want cebu lechon :('
# 0	1.00	b'head kill :('
# 0	1.00	b'want kitten badli oh god :('
# 0	1.00	b'sleep wake time :('
# 0	1.00	b'add snapchat jannygreen 22 snapchat kiksex xxx seduc tagsforlik nakamaforev hotel :('
# 0	1.00	b'probabl fault lost phone :('
# 0	1.00	b'told suicid kill ran away forev :('
# 0	1.00	b'mad wrong :( make forgiv :('
# 0	1.00	b'pleas follow conno late time zone could freak never see :('
# 0	1.00	b'biggest dream u follow brooo :('
# 0	1.00	b'lone girl england :('
# 0	1.00	b'time last week rout lovebox :( share day new prod'
# 0	1.00	b'im osad :-('
# 0	1.00	b'hate break :('
# 0	1.00	b':('
# 0	1.00	b'still happen lot unfortun still report peopl fall scam :('
# 0	1.00	b'eric made still tell love :-( fake ass'
# 0	1.00	b'miss itb omigod :('
# 0	1.00	b'need job learn drive fricken health put back :('
# 0	1.00	b'hi unfortun unabl locat origin complaint :( pl dm us product detail get back'
# 0	1.00	b'miss boyfriend :-('
# 0	1.00	b':-('
# 0	1.00	b'ehem   haha ala yeke :( okay fun kk jumpa next time    mayb '
# 0	1.00	b'come home empti hous ape :('
# 0	1.00	b'shit bestfriend :('
# 0	1.00	b'gonna inact next month :('
# 0	1.00	b'miss :('
# 0	1.00	b':( well tri someth keep mind bad thing alway'
# 0	1.00	b'never seen felt snow :('
# 0	1.00	b'work :( show get home 1.2 lost map accid lost build'
# 0	1.00	b'dont know huhu test kasi namin didnt finish ap test :-('
# 0	1.00	b'want hot dog :('
# 0	1.00	b'reject section uk govt e-petit site die :('
# 0	1.00	b'sad :('
# 0	1.00	b'cant find :('
# 0	1.00	b'oh :( build suit'
# 0	1.00	b'wanna cut k friend threw sleepov parti :( pretend ok like usual'
# 0	1.00	b'leav alon :('
# 0	1.00	b'pray khami ... :( ...'
# 0	1.00	b'damn forgot hot chocol :('
# 0	1.00	b'crave oreo milk :('
# 0	1.00	b'love island finish feel like summer gone :('
# 0	1.00	b'miss :('
# 0	1.00	b'push client way host mayb better wait till next week :('
# 0	1.00	b'im irk :('
# 0	1.00	b'someon say thank u goodby chri tomorrow pl :('
# 0	1.00	b'need nate ruess album :('
# 0	1.00	b'could realli use hug mayb icecream :('
# 0	1.00	b'lot good comic event seem kid :( part school program'
# 0	1.00	b'look like dog food ... :( ugh'
# 0	1.00	b'miss bad :('
# 0	1.00	b'aigoo babi :('
# 0	1.00	b'want watch paper town :-('
# 0	1.00	b'wanna recov :('
# 0	1.00	b':-( poor boy'
# 0	1.00	b'u guy togeth :('
# 0	1.00	b'saw one doujin think killua get fuck ging bit sad caus didnt show dick hope ginggon :('
# 0	1.00	b'comput broken wait fix miss much twitter guys.al love .. :('
# 0	1.00	b'feel like ytd :('
# 0	1.00	b'joe sick come round make soup :('
# 0	1.00	b'cri :( pdapaghimok'
# 0	1.00	b"stori life :( haha look who' talk"
# 0	1.00	b'work :( smh'
# 0	1.00	b'anyon awak :-('
# 0	1.00	b'ya sorri :-('
# 0	1.00	b'friend :('
# 0	1.00	b'use flexibl :('
# 0	1.00	b'taxi driver go realli fast scare :('
# 0	1.00	b'bet wonder happen :('
# 0	1.00	b'sheet hurt nanaman :('
# 0	1.00	b'need small ladi walk back sore ... :('
# 0	1.00	b'want meet :('
# 0	1.00	b'alex fell asleep :('
# 0	1.00	b'justin come scotland :('
# 0	1.00	b'ok write u everi week :('
# 0	1.00	b'curv tummi big .. get flat ab :('
# 0	1.00	b'look like :('
# 0	1.00	b"feel sick stomach hurt done cri night can't sleep :("
# 0	1.00	b'wait gone liter :('
# 0	1.00	b"that' quot tweet :("
# 0	1.00	b'cream pinay pie soup :('
# 0	1.00	b'one :('
# 0	1.00	b'jadi langsung flasback .. :( dont cri babyy ;('
# 0	1.00	b'okay miss :('
# 0	1.00	b'listen album live franc :('
# 0	1.00	b'time like style :| like :('
# 0	1.00	b'feel sick :('
# 0	1.00	b'account meant hit us lunch time :('
# 0	1.00	b'miss lo :('
# 0	1.00	b'pl stop say rude nicknam involv short im sick yall :('
# 0	1.00	b'miss :('
# 0	1.00	b'pl write english :( dont understand'
# 0	1.00	b'snow cold gross ew big mess everyon scrape pile anyway :('
# 0	1.00	b'hey went home na :('
# 0	1.00	b'still hope :( zayniscomingbackonjuli 26'
# 0	1.00	b'nigga dalla look like :( sale sare bandar varg'
# 0	1.00	b'hammer right ... look set day ... :('
# 0	1.00	b':( vidcon :('
# 0	1.00	b'abbi :('
# 0	1.00	b'feel like cri reason right :('
# 0	1.00	b'poor must tire :('
# 0	1.00	b'ur crazi af hurt much bc u know shit aint real edit :('
# 0	1.00	b'forev miss love lolo :('
# 0	1.00	b'xbsbabnb poor :('
# 0	1.00	b'although mum ask watch w  stilll :( read yet ask question middl movi'
# 0	1.00	b'work 5 everyday exhaust :('
# 0	1.00	b'end state last night :( :( :( :('
# 0	1.00	b'tbh prefer apma 14 idk man there someth right year apma :('
# 0	1.00	b'u give 350 ill give u 350 350 rt anyth pl :('
# 0	1.00	b'lmao back get realli realli seriou ... :('
# 0	1.00	b'wonder happen earlier realiz leadership :-( wakeupgop'
# 0	1.00	b'ah dude :('
# 0	1.00	b'wanna take adam candi eat :('
# 0	1.00	b"pleas watch infinite' mv :("
# 0	1.00	b"can't believ ill go work today wish :("
# 0	1.00	b':( hate school u dont understand miss lot blame school'
# 0	1.00	b"like can't actual put pressur ankl hop around hous lost balanc fell :("
# 0	1.00	b'bull shark :( late trafficcc'
# 0	1.00	b'miss oscar :('
# 0	1.00	b'need translat :('
# 0	1.00	b'last time one work :( fb gone check long time lol'
# 0	1.00	b'asian ummm mayb ur film child pornographi slutsham fake suicid ect :-('
# 0	1.00	b'poland faraway germani girl :( still believ one day meet'
# 0	1.00	b"good quit full time job last week can't find anoth one :("
# 0	1.00	b':( well cooki better worth'
# 0	1.00	b"lmao catch point watch weekli ok make 700 there' 800 ep :("
# 0	1.00	b"cake look amaz can't believ miss :("
# 0	1.00	b'keep forget area :-( want visit next time xx'
# 0	1.00	b'make want watch whole film cgi kick oop pun start grumbl turn :('
# 0	1.00	b'see delph anoth kit upset :('
# 0	1.00	b"miss :( haha x'   still rememb u hate xxx"
# 0	1.00	b'zayniscomingbackonjuli 26 funni :('
# 0	1.00	b'allow cheat meal :('
# 0	1.00	b'fun osaka super junior :( would love watch comeback stage though'
# 0	1.00	b'aytona hala guy get readi na mathird wheel :( jkjk'
# 0	1.00	b'worst day ever :( pain ...'
# 0	1.00	b'backtrack 3 hour :( ... time start actual util list'
# 0	1.00	b'surviv anoth week without phone :('
# 0	1.00	b'wish :('
# 0	1.00	b'pat jay'
# 0	1.00	b'sad stori broh :('
# 0	1.00	b'uh asleep :('
# 0	1.00	b'need boyfriend rn answer calll :('
# 0	1.00	b'icaru 500 awn unfortun fit 600 size :('
# 0	1.00	b'2 bach :('
# 0	1.00	b'6 day left :('
# 0	1.00	b'pleas babi follow :('
# 0	1.00	b"there' noth :-("
# 0	1.00	b"can't feel tomorrow :("
# 0	1.00	b'give work old staff come polic later court look anoth job :( bye bye'
# 0	1.00	b"landlord like mp' though that' go easi :-("
# 0	1.00	b'look old photo get sad :('
# 0	1.00	b'oh :( hope everyth okay'
# 0	1.00	b"want want want follow want want want that' crazi :( pleas love (:  "
# 0	1.00	b'bullshit :('
# 0	1.00	b'nugget fri :-('
# 0	1.00	b'love warrior :-('
# 0	1.00	b'tire eat :('
# 0	1.00	b'dame assign :('
# 0	1.00	b'watch gossip girl make sad :('
# 0	1.00	b'tomorrow :('
# 0	1.00	b'still realli miss purpl hair tie :('
# 0	1.00	b"can't deal match unless ishii fuck everyth :("
# 0	1.00	b'clara yile left :('
# 0	1.00	b'whatev stil l young >:-('
# 0	1.00	b'last chanc :('
# 0	1.00	b':('
# 0	1.00	b'look like cri look like cri bit :('
# 0	1.00	b'come onlin follow peopl :/ z wrong u ignor sidharth :( :('
# 0	1.00	b'lol lazi learn ps :('
# 0	1.00	b'sleep'
# 0	1.00	b'bad day :-('
# 0	1.00	b'tagal :('
# 0	1.00	b'oh ndabenhl :-( pleas let us know feel way sa'
# 0	1.00	b'got one poorli doggi :('
# 0	1.00	b'repli pleas antag :('
# 0	1.00	b'window 7 :('
# 0	1.00	b'well p 41 8 page note thu far :-( read twice'
# 0	1.00	b'want kyli jenner cloth :('
# 0	1.00	b'ye unfortun done whole troubleshoot box still issu :('
# 0	1.00	b"miss convo' bad damn :("
# 0	1.00	b'dem free tix big bang concert :('
# 0	1.00	b'your gonna guess what insid box :('
# 0	1.00	b'idk :-( mayb think boob fun play'
# 0	1.00	b'jahat :('
# 0	1.00	b'sorri :( longer abl access site automat redirect local site'
# 0	1.00	b'mad gigi dream hang didnt want talk :('
# 0	1.00	b'carter deserv hate :( deserv singl corn chip deserv two corn chip'
# 0	1.00	b'nnnooo cz daddi gorilla anymor ... :('
# 0	1.00	b'still 6 hour work left omg :('
# 0	1.00	b'link miss hbm :('
# 0	1.00	b'freak humid think never get use even 100 japanes :('
# 0	1.00	b'school work :('
# 0	1.00	b":( longer admir consist jason shackell' hair podcast"
# 0	1.00	b'envi peopl get meet pictur laura taylor lana etc lucki meet babi :('
# 0	1.00	b'want sa bday ko :( :( :( <3'
# 0	1.00	b':-( pleas notic gonna spam u till u follow babi'
# 0	1.00	b'kik twer 782 kik kikhorni lesbian hornykik girl countrymus hornykik :('
# 0	1.00	b'need hug :('
# 0	1.00	b'word explain much miss hope know :('
# 0	1.00	b'oh gfriend perform rn :('
# 0	1.00	b'ok :-( w hahaahahahaha'
# 0	1.00	b'sm1 bad mean got mutil robot shot wall know could destroy ... >:('
# 0	1.00	b'dare :('
# 0	1.00	b'good morn twitter friend hope amaz day freakin tire need sleep :('
# 0	1.00	b' haestarr  :('
# 0	1.00	b'wish help :('
# 0	1.00	b'good alway  fli back today though :('
# 0	1.00	b'need car function car :('
# 0	1.00	b'wish twitter would support audio record would send yall snippet amaz :('
# 0	1.00	b'et brotherhood steel :('
# 0	1.00	b':-( pleas notic mefd'
# 0	1.00	b'miss diana :('
# 0	1.00	b'master figur turn led gold doom :('
# 0	1.00	b'want pull nighter sleepi alreadi :('
# 0	1.00	b'ever wanna sleeep :( let mee'
# 0	1.00	b'oh allow vote teen choic award :( said area'
# 0	1.00	b'want icon selfi jack :('
# 0	1.00	b':-( pleas notic meowkd'
# 0	1.00	b"twitter turn much complic can't find trend :("
# 0	1.00	b'right tire :( good night alli love  '
# 0	1.00	b' wish channel watch :( usual watch onlin laptop anymor :/'
# 0	1.00	b'rude :('
# 0	1.00	b"would want peopl understand busi daili schedul  c'mon guy bare even get 5 hour sleep :-("
# 0	1.00	b':( kill'
# 0	1.00	b'think she busi :('
# 0	1.00	b"swimmer' ear kasi :("
# 0	1.00	b'want bday answer pleas  idk leh :( b'
# 0	1.00	b'yeahhh ... :( tht corner b rememb alway coz gg ... :( n bb didnot show th clip episod :('
# 0	1.00	b'releas onlin album know :('
# 0	1.00	b':-( pleas notic h'
# 0	1.00	b'   thank san  wanna chang avi usanel :('
# 0	1.00	b'sad day nathan :('
# 0	1.00	b'noo sad time :( rubi replac shuffl act'
# 0	1.00	b'got excit micha rt fave tweet creep :-('
# 0	1.00	b'anyon wanna friend lone girl england bore hell throughout summer holiday .. :('
# 0	1.00	b'home alon :('
# 0	1.00	b'whose idea ave tripl busi lectur friday afternoon 2-5 :('
# 0	1.00	b':('
# 0	1.00	b"that' damn lie :("
# 0	1.00	b'allow give blood :('
# 0	1.00	b'six month ago bottom jaw second tooth back broke quarter ... thing chew gum :('
# 0	1.00	b'go sleep 12 last night rn im :('
# 0	1.00	b':-( pleas notic'
# 0	1.00	b'twitter decid take featur away :-('
# 0	1.00	b'okay tire plan go today rain :('
# 0	1.00	b'that push emoji give soni five :-( :-( :-( :-( :-( :-('
# 0	1.00	b'late :( followmeaaron'
# 0	1.00	b'tzelumxoxo dont realli use line ipod :-( use whatsapp actual'
# 0	1.00	b'buy someth drank caus noth :('
# 0	1.00	b"slept day can't sleep :("
# 0	1.00	b':-( pleas notic mew'
# 0	1.00	b'peopl :( r u'
# 0	1.00	b'indic sm receiv :('
# 0	1.00	b'got regular :('
# 0	1.00	b'kik ouliv 70748 kik kikmenow photo babe loveofmylif brasileirao viernesderolenahot :('
# 0	1.00	b'feel u :('
# 0	1.00	b'longmorn 30 suppos replac tobermori 32 ... begin strong tail miss :('
# 0	1.00	b'wait love recuerda tanto bath :('
# 0	1.00	b'sun gone :('
# 0	1.00	b'die movi :('
# 0	1.00	b'shit .. suggest na suck muna :( know hard nurs import right'
# 0	1.00	b':(  issu'
# 0	1.00	b'hrryok fact harri still hold mom  hand :( :( :('
# 0	1.00	b'much await excit go bore friday weekend :('
# 0	1.00	b':( asleep'
# 0	1.00	b'babi :('
# 0	1.00	b'hp curs child book play :('
# 0	1.00	b'ur crazi af u want hurt urslef edit stuff lime u know shit aint real :( '
# 0	1.00	b'omg r hahah :( omg debut mo na next year :('
# 0	1.00	b'wish could meet boy one day :('
# 0	1.00	b'tri keep hous use buy truckload miss 13 favour :('
# 0	1.00	b':-('
# 0	1.00	b"best spectat sail uk w'end bbc show highlight :(  fli  foil ac45 catamaran"
# 0	1.00	b'mayb :('
# 0	1.00	b'guy add kik peli 829 kik kikmenow fuck model amateur elfindelmundo sextaatequemfimseguesdvcomvalentino :('
# 0	1.00	b"could pl take care server befor send valu long can't get :("
# 0	1.00	b'love babi sweet cinnamon best :('
# 0	1.00	b'comfort :('
# 0	1.00	b'mtap tomorrow mean sleep earli tonight :-('
# 0	1.00	b'peng bestfriend :( psygustokita'
# 0	1.00	b'frozen bagu emang :('
# 0	1.00	b'wish could dm cute thing :( prefer cute kitten puppi'
# 0	1.00	b'still get paper engg go back cmc mage okay :('
# 0	1.00	b"that' kind dumb statement like moodsw like make tweet say hate termin diseas :( like wow uniqu"
# 0	1.00	b'slow news day :-('
# 0	1.00	b':-( pleas notic men'
# 0	1.00	b'watch us :('
# 0	1.00	b'regret regret :('
# 0	1.00	b'even though seen whole peep show multipl time noth could prepar netflix remov seri 1 7 ... :('
# 0	1.00	b"that' said ... :("
# 0	1.00	b'way get bandana :('
# 0	1.00	b"hi oh :( let' take look pleas chat us"
# 0	1.00	b'sad moment u r leav two day :('
# 0	1.00	b':-( pleas notic mef'
# 0	1.00	b'rebound run away alreadi pooor :('
# 0	1.00	b'lol 2am last night face though peopl think perpetu piss sad b c rest bitchfac :('
# 0	1.00	b':-( miss fun'
# 0	1.00	b':-( pleas notic z'
# 0	1.00	b'peopl wish birthday :('
# 0	1.00	b':( world aw'
# 0	1.00	b'let feel like complet shit :('
# 0	1.00	b'uh huh :( two time super clever like'
# 0	1.00	b':( bitch realli went'
# 0	1.00	b'fave unfollow :(  '
# 0	1.00	b'realli want visit iceland :('
# 0	1.00	b'zayn_come_back_we_miss_y <3 <3 :( much'
# 0	1.00	b'starv :-('
# 0	1.00	b'bc feel creepi today pmsl mianh milkeu :('
# 0	1.00	b'wanna meet boy :('
# 0	1.00	b'internet total bitch'
# 0	1.00	b'lrt bambam like soda :( meant :('
# 0	1.00	b'1 :('
# 0	1.00	b'wish could go shop whole weekend taken :( annoy'
# 0	1.00	b'peopl usual stay asleep wtf :('
# 0	1.00	b'cheer :-('
# 0	1.00	b'payback like video tri help get kit kat :('
# 0	1.00	b'even tire :-('
# 0	1.00	b'one come smoke :('
# 0	1.00	b'87000 jobe deliveri pl :('
# 0	1.00	b'happi birthday be enjoy day beb love miss sooo muchi :( see soon sana     '
# 0	1.00	b'cuti :('
# 0	1.00	b'alway fall asleep earli text someon :('
# 0	1.00	b'say icecream avail :('
# 0	1.00	b'ask go bathroom :-( realli enjoy show though'
# 0	1.00	b'lagg much certain peopl :('
# 0	1.00	b'need clear head :('
# 0	1.00	b'babi went back sleep bore :-('
# 0	1.00	b'ughh got noth pain :('
# 0	1.00	b'laper banget :('
# 0	1.00	b"naw :( deep dream novel hope there'd invis page beast scuttl around there' worm track"
# 0	1.00	b'bauuukkk :('
# 0	1.00	b"bad guy cant attend today' music bank :("
# 0	1.00	b'worri :-('
# 0	1.00	b' mine ...'
# 0	1.00	b'care muslim :('
# 0	1.00	b':('
# 0	1.00	b'jessica call quit power ab 5:15 :-('
# 0	1.00	b'lost us friend ... :( one start argument'
# 0	1.00	b'hope fun vidcon rlli bum couldnt go :( love sunshin   '
# 0	1.00	b'yepp .. get bore :('
# 0	1.00	b'last night good :(    '
# 0	1.00	b'follow :('
# 0	1.00	b'feelin sick :('
# 0	1.00	b'want biscuit slather chocol definit tax boo :('
# 0	1.00	b'investig answer especi pup die within free insur period :('
# 0	1.00	b'jsut end :('
# 0	1.00	b'heart hurt real bad :('
# 0	1.00	b'aw :('
# 0	1.00	b'follow pl :('
# 0	1.00	b'realist ... :('
# 0	1.00	b'happi princess today :( sigh get work done x purpl princess edit'
# 0	1.00	b'babee :( demn hotaisndonwyvauwjoqhsjsnaihsuswtf'
# 0	1.00	b'someth wrong :('
# 0	1.00	b'word explain way miss :('
# 0	1.00	b'think need 2 year train beat record sia :('
# 0	1.00	b'niram ya geng :( fikri anna 6 other tirtagangga hotel '
# 0	1.00	b'char im realli sick :( one font size 8 minion float font size 12 sick kid pl :('
# 0	1.00	b'bestfriend like ed plsss :('
# 0	1.00	b'riprishikeshwari soul rest peac :('
# 0	1.00	b':( unfollow like 300 peopl caus follow 1k peopl difficult'
# 0	1.00	b'enough time listen artist music :-('
# 0	1.00	b'take ice creamist pleasee :('
# 0	1.00	b'alway go terribl time :('
# 0	1.00	b':-( challeng though pleas check fb page entri rather substitut thank'
# 0	1.00	b"can't even see hyungwon :("
# 0	1.00	b'tell pl eat :-('
# 0	1.00	b'that life get call peopl havent seen 20 year alway favour'
# 0	1.00	b'omg :( everi time would complain skin mom everyon get pimpl like although'
# 0	1.00	b'letsfootbal atk greymind 43 break news chri gayl say cricket 2-3 month due back surgeri :( cplt 20 cp '
# 0	1.00	b"miss hannah montana that' raven sooo much :-("
# 0	1.00	b'want rt :('
# 0	1.00	b'gonna okay love :('
# 0	1.00	b'awh :-(  stay '
# 0	1.00	b'last full night greec :( opu inner pleasur'
# 0	1.00	b'disappoint hear especi invest one :-('
# 0	1.00	b'ye :( bbq attend'
# 0	1.00	b'work :('
# 0	1.00	b'three 190 row 33 :('
# 0	1.00	b'throat hurt bad :('
# 0	1.00	b'lolliv :('
# 0	1.00	b'im watch disney channel :('
# 0	1.00	b'nobodi pick one right :('
# 0	1.00	b'someon gift :( calibraskaep need bad'
# 0	1.00	b'lol got split hard lol singl singl split collat spilt singl singl spilt singl split singl singl collat :('
# 0	1.00	b'hope feel better jay :('
# 0	1.00	b'ye mani time :( quitkarwaoyaaro'
# 0	1.00	b'stu deactiv :('
# 0	1.00	b'disappoint :( never ever lucki handl jabongatpumaurbanstamped'
# 0	1.00	b'hello need 2.5 g2a code pl :('
# 0	1.00	b'thesi thesi thesi thesi thesi thesi thesi thesi thesi thesi sherep nemen ng behey ke :('
# 0	1.00	b'deactiv acc :( otwolgrandtrail'
# 0	1.00	b'still sad kick epic motherfuck :('
# 0	1.00	b'realli want anoth tattoo :('
# 0	1.00	b'someon get mad reec vm tomorrow pleas never one :('
# 0	1.00	b'deth deth dont leav :('
# 0	1.00	b'true :-('
# 0	1.00	b"let' go  cast vote got 7 today :("
# 0	1.00	b'someon hug pl :('
# 0	1.00	b'omg :( gonna happen yeah wish ..'
# 0	1.00	b':( lest gp get'
# 0	1.00	b'aww :( catch departur'
# 0	1.00	b'appar isnt :('
# 0	1.00	b'miss day :( toothsensit'
# 0	1.00	b'unavail :('
# 0	1.00	b"mean can't wipe :-("
# 0	1.00	b'found flight home 13 hour long :('
# 0	1.00	b'ugh yuck :( make sure rest next two day'
# 0	1.00	b'omg sad birthday sorri didnt send someth ystrday ill later cuz dont phone :('
# 0	1.00	b'seolhyun isnt first ep she film drama :('
# 0	1.00	b'sorri :('
# 0	1.00	b'alway get like 5 4 piec spici nugget :('
# 0	1.00	b'im sooo hungri though :('
# 0	1.00	b'thigh cramp :-('
# 0	1.00	b'fellow morn owl sure notic sun alreadi rise bit later ... sign winter come :('
# 0	1.00	b'nowher near tire :('
# 0	1.00	b'hot :('
# 0	1.00	b'dude :( scare lol'
# 0	1.00	b'rain whole day mumbai  feel like work :('
# 0	1.00	b"best get littl ladi pj' need go wallpap mom :( realli cba today"
# 0	1.00	b'ye pl far need :('
# 0	1.00	b'even know could get hotter fml :('
# 0	1.00	b'aw bless made smile miss :('
# 0	1.00	b'hi life :('
# 0	1.00	b'mood whole day :-('
# 0	1.00	b'almost done park rec :( lol'
# 0	1.00	b'u come back :('
# 0	1.00	b'hi sorri hear :( log'
# 0	1.00	b'gotdamn :-('
# 0	1.00	b'want phone baaack :('
# 0	1.00	b'honest miss dubai dubai miss want come back :('
# 0	1.00	b'final get star driver srw mobag :('
# 0	1.00	b'sad reason suck u dunno stop sad u gotta chill ur room listen music b alon :('
# 0	1.00	b'stream pass melon pleas stream much  digit bad :('
# 0	1.00	b'snapchat jannygreen 18 snapchat kiksex hot teen lgbt goodmus sexcam :('
# 0	1.00	b'aw :( stroke'
# 0	1.00	b'first saw gnr open alic cooper famou parti backstag alic r slash :('
# 0	1.00	b'tag  sorri lot music prolli know half :( also'
# 0	1.00	b'24 hour enough :('
# 0	1.00	b'awww poor bunni :('
# 0	1.00	b'stress let go :('
# 0	1.00	b'wish blooper :('
# 0	1.00	b'love u fuck know :('
# 0	1.00	b'yeah :('
# 0	1.00	b'noth though :('
# 0	1.00	b'aww alreadi left would come said hey seen sooner :( good night x'
# 0	1.00	b'weird :('
# 0	1.00	b'sr financi analyst expedia inc bellevu wa'
# 0	1.00	b'serious :('
# 0	1.00	b'tri make prison style alcohol fail badli end massiv dose shit ... :('
# 0	1.00	b'fair still look cute :('
# 0	1.00	b'hi love u :( :('
# 0	1.00	b'overli attach :('
# 0	1.00	b"m' voic :( lord help"
# 0	1.00	b'want bandana bottl set huhuh :('
# 0	1.00	b"can't sleep bc heartburn :-("
# 0	1.00	b'meet steven kid listen :('
# 0	1.00	b'fuck jealou everyon holiday :('
# 0	1.00	b'terribl thing doin yoga work stop start ... awalmu njareeem :('
# 0	1.00	b'nooo last day today :('
# 0	1.00	b'care maggi psycho bitch want kill take two day vacat twitter :( wahhh'
# 0	1.00	b'realli look forward work tonight though :('
# 0	1.00	b'miss abudhabi :('
# 0	1.00	b'go home blue :-( back monday hiby social action plan shareyoursumm'
# 0	1.00	b'pro soccer play would cool :('
# 0	1.00	b'wish b8 strong :('
# 0	1.00	b"hey girl must.b dairi produxt want can't lactos intoler :("
# 0	1.00	b'midland ye thank depress weather forecast word rain mention sever time :-('
# 0	1.00	b'cri :('
# 0	1.00	b'old one day ... :('
# 0	1.00	b'liter spent day yesterday sleep bed still absolut fuck knacker today :('
# 0	1.00	b'new sandra bland footag realli ice cake .. heartbreak drag lifeless bodi polic car :('
# 0	1.00	b'knowww :('
# 0	1.00	b'sorri feel way shell :( regularli review price offer best'
# 0	1.00	b'sorri hear jess :( quickest way call 44 7782 333 333 add account within 72 hour'
# 0	1.00	b'pengen box :( '
# 0	1.00	b'girlll u hear abt possibl tsunami us west indi im island im afraid lol :('
# 0	1.00	b'snap :('
# 0	1.00	b'would love see w nick pick one waist tv time never work anyway :('
# 0	1.00	b'hulk hogan news racial tirad :( thought couldnt stoop lower role thunder paradis'
# 0	1.00	b'sorri forget import day huhu fight im sorri :('
# 0	1.00	b'break habit lifetim ... play call duti game .. :('
# 0	1.00	b'apolog annoy much snapchat :('
# 0	1.00	b'adult take thing seriou realli miss kid :('
# 0	1.00	b'facad democraci drop quickli :('
# 0	1.00	b'confus brat :('
# 0	1.00	b'someon come make popcorn watch movi pl cuddl :('
# 0	1.00	b'final home drive sinc 5am :('
# 0	1.00	b"tb mr o' class :("
# 0	1.00	b'bade fursat se usey banaya hai usey uppar waal ney afso hums dur hai wo :('
# 0	1.00	b"oh realli :( saw gif post seen realli happi mayb peopl who'd happi naruhina"
# 0	1.00	b"can't :("
# 0	1.00	b'that english namee :( haiqal isnt english name rememb'
# 0	1.00	b'want dont paypal :('
# 0	1.00	b"that' 360hr summer end ... huhuhu miss picc lot :("
# 0	1.00	b'heart hurt :('
# 0	1.00	b'instor card expir june havent sent new one :('
# 0	1.00	b'mcountdown pre-vot begin 5th place :('
# 0	1.00	b'felt bad iren forgot go say :('
# 0	1.00	b"wow that' great what' usernam :("
# 0	1.00	b'minho still injur :( get well oppa miss <3'
# 0	1.00	b"can't even deliv ice cream tri twice ice cream van busi :("
# 0	1.00	b'want durian strudel :('
# 0	1.00	b'vidcon :('
# 0	1.00	b'guy add snapchat amargolonnard snapchat kikmeboy sexi french dirtykik newmus sexcam :('
# 0	1.00	b'u chang u say chang tsk :('
# 0	1.00	b'damn .. wish could sleep :('
# 0	1.00	b'like join marin :-('
# 0	1.00	b'sad yall thought real :('
# 0	1.00	b'go :( kailan ba may tix ka'
# 0	1.00	b'alreadi kill tho :('
# 0	1.00	b'hotel dog pretti sad brother sister got separ :('
# 0	1.00	b'miss cute someon la :('
# 0	1.00	b'payday feel like payhour gone bill immedi :('
# 0	1.00	b'lmao :( natur hair seen ugli swear'
# 0	1.00	b'nope :( best place get first pre-ord amazon'
# 0	1.00	b'sunday littl abl get much year busi :( look great tho'
# 0	1.00	b'fwm :('
# 0	1.00	b"what' wrong :("
# 0	1.00	b'miss guppi :-('
# 0	1.00	b'go away ... must go dentist :( poorkid'
# 0	1.00	b'thank lack time problem :('
# 0	1.00	b'get misunderstood :('
# 0	1.00	b'ur cat super nice cuddli suddenli scratch tri bite :( like trust anymor'
# 0	1.00	b'hit thumb :('
# 0	1.00	b'almost got see cute ankl sock :('
# 0	1.00	b'honestli point care compens want abl play bf :('
# 0	1.00	b'song :('
# 0	1.00	b'awww babi :( '
# 0	1.00	b'sleep last night n help wake 8 morn n phone even charg :('
# 0	1.00	b'pleas tell everyon didnt go vidcon :('
# 0	1.00	b'need like tell na na okay lang :('
# 0	1.00	b'follow back :('
# 0	1.00	b'heart current tortur :( lol wat'
# 0	1.00	b'femal student kill cast love kirkiri :('
# 0	1.00	b'run bread feel well enough make :('
# 0	1.00	b'dream :('
# 0	1.00	b":( broken heart that' phase worri"
# 0	1.00	b'stop sour :( suit  '
# 0	1.00	b'wonho remind someon >:( cant put finger'
# 0	1.00	b'wont work today feel ill :( tummi bug xx'
# 0	1.00	b'last day beach :-( :-( :-( ...'
# 0	1.00	b'rain :('
# 0	1.00	b'visual studio 2015 got switch alreadi broke lot code :('
# 0	1.00	b"serious unfair ask question readi answer win :( ='( busi ask question"
# 0	1.00	b'mission bear fail :('
# 0	1.00	b':-( ugli af :-('
# 0	1.00	b'pap spirit anim  dont :('
# 0	1.00	b"total ship danzel craft can't go vidcon would sell soul devil get hug dan phil :("
# 0	1.00	b'hate :('
# 0	1.00	b'gona miss sheff utd york probabl wait visa leav gim 1 friendli bet start season bench :('
# 0	1.00	b'lead us gone :('
# 0	1.00	b'   mess :('
# 0	1.00	b'ironi harm .. :('
# 0	1.00	b'miss much :( xxx'
# 0	1.00	b'motiv :('
# 0	1.00	b'point yolo sort die lactos ... ugh like 3 month pregnant bloat :('
# 0	1.00	b'realli sorri cant find imag mention :('
# 0	1.00	b'im get olli tweet notif :('
# 0	1.00	b'go home tomorrow :-('
# 0	1.00	b'bad poor :('
# 0	1.00	b'team kill :('
# 0	1.00	b'way :('
# 0	1.00	b'inact :('
# 0	1.00	b':( world alterni kill realli sad leav place everyon die'
# 0	1.00	b'everyon gonna talk abt rat boy today bc :('
# 0	1.00	b'earth assum rain london like influenc overal warm dri past week continent europ :('
# 0	1.00	b'rememb fab four 24 hour call damn miss much :('
# 0	1.00	b'  r u sure u want b r u h bare surviv w tank top :('
# 0	1.00	b'thirsti :('
# 0	1.00	b'konami polici pe pc version happen version :('
# 0	1.00	b'sound effect :('
# 0	1.00	b'blame ranti :('
# 0	1.00	b'ummm ok new develop :('
# 0	1.00	b'guy never :(  aw sorri realli bust atm .. shall back soon'
# 0	1.00	b'bad :( like video mani pervers'
# 0	1.00	b'first time go school without bracelet :( feel odd'
# 0	1.00	b"can't fall back asleep :("
# 0	1.00	b'im twin follow back bylfnnz :('
# 0	1.00	b'unfair .. u ban film pakistan :('
# 0	1.00	b'want one :('
# 0	1.00	b'feel sick :('
# 0	1.00	b'hmmm 10 min get train current 15 min away :( failsatlif'
# 0	1.00	b'hungri :('
# 0	1.00	b'want birthday alreadi :('
# 0	1.00	b'complet agre press :('
# 0	1.00	b'im super duper tire :('
# 0	1.00	b'bore time :( know ...'
# 0	1.00	b'ill soon promis :( waaah'
# 0	1.00	b'wanna chang avi usanel :('
# 0	1.00	b'puppi broke foot :('
# 0	1.00	b"where' jaebum babi pictur :("
# 0	1.00	b'mr ahmad maslan cook :('
# 0	1.00	b'hull support expect misser week :-('

# %% [markdown]
# # Predice con tu propio tweet

# %%
# Test with your own tweet - feel free to modify `my_tweet`
my_tweet = 'I am happy because I am learning :)'

p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
print(p)
# Out:
# 0.005812894083588998

# %% [markdown]
# ### Clase para Análisis de Sentimientos

# %%
import re
from collections import defaultdict, Counter
import math

#  Implementación de Naive Bayes desde cero 
class NaiveBayesTexto:
    def __init__(self, alpha=1.0):  # alpha = suavizado de Laplace
        self.alpha = alpha
        self.clases = []
        self.prior = {}           # P(clase)
        self.likelihood = {}      # P(palabra | clase)
        self.vocabulario = set()
    
    def _tokenizar(self, texto):
        return re.findall(r'\b[a-záéíóúüñ]+\b', texto.lower())
    
    def entrenar(self, textos, etiquetas):
        self.clases = list(set(etiquetas))
        n_docs = len(textos)
        
        # Agrupar tokens por clase
        tokens_por_clase = defaultdict(list)
        for texto, etiqueta in zip(textos, etiquetas):
            tokens = self._tokenizar(texto)
            tokens_por_clase[etiqueta].extend(tokens)
            self.vocabulario.update(tokens)
        
        V = len(self.vocabulario)
        
        # Calcular prior P(clase)
        conteo_clases = Counter(etiquetas)
        self.prior = {c: conteo_clases[c] / n_docs for c in self.clases}
        
        # Calcular likelihood P(palabra|clase) con suavizado Laplace
        self.likelihood = {}
        for clase in self.clases:
            conteo = Counter(tokens_por_clase[clase])
            total = sum(conteo.values())
            self.likelihood[clase] = {
                palabra: (conteo.get(palabra, 0) + self.alpha) / (total + self.alpha * V)
                for palabra in self.vocabulario
            }
            self.likelihood[clase]['__OOV__'] = self.alpha / (total + self.alpha * V)
    
    def predecir_uno(self, texto):
        tokens = self._tokenizar(texto)
        log_probs = {}
        for clase in self.clases:
            log_prob = math.log(self.prior[clase])
            for token in tokens:
                p = self.likelihood[clase].get(token, self.likelihood[clase]['__OOV__'])
                log_prob += math.log(p)
            log_probs[clase] = log_prob
        return max(log_probs, key=log_probs.get), log_probs
    
    def predecir(self, textos):
        return [self.predecir_uno(t)[0] for t in textos]

# %%
# Dataset Dummy de reseñas de películas (muestra representativa)
resenas = [
    # Positivas
    ("Esta película es absolutamente maravillosa, una obra maestra del cine.", 1),
    ("Increíble actuación, historia emocionante y efectos visuales impresionantes.", 1),
    ("Me encantó cada minuto, el director hizo un trabajo extraordinario.", 1),
    ("Una experiencia cinematográfica única, llena de emoción y belleza.", 1),
    ("Perfecta en todos los sentidos, la recomiendo ampliamente.", 1),
    ("El guion es brillante y los actores dan lo mejor de sí mismos.", 1),
    ("Simplemente espectacular, la mejor película del año sin duda.", 1),
    ("Emocionante de principio a fin, con giros inesperados magníficos.", 1),
    ("Una historia inspiradora contada de manera magistral.", 1),
    ("Gran película, entretenida y con un mensaje poderoso.", 1),
    ("Actuaciones sobresalientes y fotografía impecable.", 1),
    ("Un film que te deja pensando por días, brillantemente ejecutado.", 1),
    # Negativas
    ("Terrible película, una pérdida total de tiempo y dinero.", 0),
    ("Aburrida, predecible y con actuaciones pésimas.", 0),
    ("El peor filme que he visto en años, sin argumento ni emoción.", 0),
    ("Decepcionante y aburrida, no la recomiendo para nada.", 0),
    ("Historia sin sentido, personajes vacíos y final horrible.", 0),
    ("Mala actuación, pésimo guion y efectos especiales ridículos.", 0),
    ("Una completa decepción, esperaba mucho más de este director.", 0),
    ("Tediosa e insulsa, me quedé dormido a la mitad.", 0),
    ("Los diálogos son terribles y la trama no tiene coherencia alguna.", 0),
    ("Desperdicio de talento, película mediocre sin ningún valor.", 0),
    ("El argumento es ridículo y los efectos visuales son horribles.", 0),
    ("Nada funciona en esta película, es un fracaso absoluto.", 0),
]

textos  = [r for r, _ in resenas]
etiquetas = [e for _, e in resenas]

print(f"Total de reseñas: {len(resenas)}")
print(f"Positivas: {sum(etiquetas)}")
print(f"Negativas: {len(etiquetas) - sum(etiquetas)}")
print()
print("Ejemplos:")
for t, e in resenas[:3]:
    print(f'  [{("POS" if e==1 else "NEG")}] {t}')
# Out:
# Total de reseñas: 24
# Positivas: 12
# Negativas: 12
#
# Ejemplos:
#   [POS] Esta película es absolutamente maravillosa, una obra maestra del cine.
#   [POS] Increíble actuación, historia emocionante y efectos visuales impresionantes.
#   [POS] Me encantó cada minuto, el director hizo un trabajo extraordinario.

# %%
# Entrenar y evaluar 
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    textos, etiquetas, test_size=0.3, random_state=42, stratify=etiquetas
)

nb = NaiveBayesTexto(alpha=1.0)
nb.entrenar(X_train, y_train)

y_pred = nb.predecir(X_test)
correctas = sum(p == r for p, r in zip(y_pred, y_test))
print("=== Naive Bayes DESDE CERO ===")
print(f"Train: {len(X_train)} | Test: {len(X_test)}")
print(f"Accuracy: {correctas}/{len(y_test)} = {correctas/len(y_test):.1%}")
print()
# Out:
# === Naive Bayes DESDE CERO ===
# Train: 16 | Test: 8
# Accuracy: 2/8 = 25.0%

# %% [markdown]
# ## Ventajas y limitaciones
#
# **Ventajas**
# - Rapido de entrenar y predecir, incluso con mucho texto.
# - Funciona bien con **pocos datos**.
# - Buen *baseline* (linea base) para clasificacion de texto.
# - Facil de interpretar.
#
# **Limitaciones**
# - La suposicion de independencia es **falsa** (las palabras si se relacionan).
# - Ignora el **orden** y el **contexto** (ej. negaciones: *"no es buena"*).
# - No captura sarcasmo ni ironia.

# %% [markdown]
# **Lecturas:**
# - Jurafsky & Martin - *Speech and Language Processing*, Cap. 4 ([PDF gratuito](https://web.stanford.edu/~jurafsky/slp3/4.pdf)) - muy recomendado, cubre Naive Bayes y analisis de sentimientos en detalle.
# - Bird, Klein & Loper - *Natural Language Processing with Python* ([NLTK Book](https://www.nltk.org/book/)), Cap. 6.
